# %% [markdown]
# #### This file shows the following skills:
# - Creation of VIEW tables.
# - Data security, hiding sensitive information.
# - Frequently used query
# - Displaying the VIEW's definition
# - Concealing complexity queries to make the life of analysts easier so they won't - have to use joins.
# - Data aggregation.
# - Updating data in a VIEW.

# %% [markdown]
# Loading SQL extension

# %%
# %load_ext sql

# %% [markdown]
# Connecting to the LMU Build sakila database

# %%
# %sql mysql://itaylmub_dba:****@lmu.build/itaylmub_sakila

# %% [markdown]
# ### VIEW Syntax
#
# ```
# CREATE [OR REPLACE] VIEW view_name AS
#     SELECT columns
#     FROM tables
#     [WHERE conditions];
# ```

# %% [markdown]
# ## 1. Frequently used query
#
#
# Who are our active customers?
# Creating a VIEW for our active customers. Returning all columns.

# %%
# %%sql
# CREATE OR REPLACE VIEW active_customer AS
#     SELECT *
#     FROM customer
#     WHERE active = 1;
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 0 rows affected.
# []

# %% [markdown]
# ### SELECT from the VIEW

# %%
# %%sql
# SELECT *
# FROM active_customer;
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 584 rows affected.
# [(1, 1, 'MARY', 'SMITH', 'MARY.SMITH@sakilacustomer.org', 5, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (2, 1, 'PATRICIA', 'JOHNSON', 'PATRICIA.JOHNSON@sakilacustomer.org', 6, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (3, 1, 'LINDA', 'WILLIAMS', 'LINDA.WILLIAMS@sakilacustomer.org', 7, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (4, 2, 'BARBARA', 'JONES', 'BARBARA.JONES@sakilacustomer.org', 8, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (5, 1, 'ELIZABETH', 'BROWN', 'ELIZABETH.BROWN@sakilacustomer.org', 9, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (6, 2, 'JENNIFER', 'DAVIS', 'JENNIFER.DAVIS@sakilacustomer.org', 10, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (7, 1, 'MARIA', 'MILLER', 'MARIA.MILLER@sakilacustomer.org', 11, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (8, 2, 'SUSAN', 'WILSON', 'SUSAN.WILSON@sakilacustomer.org', 12, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (9, 2, 'MARGARET', 'MOORE', 'MARGARET.MOORE@sakilacustomer.org', 13, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (10, 1, 'DOROTHY', 'TAYLOR', 'DOROTHY.TAYLOR@sakilacustomer.org', 14, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (11, 2, 'LISA', 'ANDERSON', 'LISA.ANDERSON@sakilacustomer.org', 15, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (12, 1, 'NANCY', 'THOMAS', 'NANCY.THOMAS@sakilacustomer.org', 16, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (13, 2, 'KAREN', 'JACKSON', 'KAREN.JACKSON@sakilacustomer.org', 17, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (14, 2, 'BETTY', 'WHITE', 'BETTY.WHITE@sakilacustomer.org', 18, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (15, 1, 'HELEN', 'HARRIS', 'HELEN.HARRIS@sakilacustomer.org', 19, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (17, 1, 'DONNA', 'THOMPSON', 'DONNA.THOMPSON@sakilacustomer.org', 21, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (18, 2, 'CAROL', 'GARCIA', 'CAROL.GARCIA@sakilacustomer.org', 22, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (19, 1, 'RUTH', 'MARTINEZ', 'RUTH.MARTINEZ@sakilacustomer.org', 23, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (20, 2, 'SHARON', 'ROBINSON', 'SHARON.ROBINSON@sakilacustomer.org', 24, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (21, 1, 'MICHELLE', 'CLARK', 'MICHELLE.CLARK@sakilacustomer.org', 25, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (22, 1, 'LAURA', 'RODRIGUEZ', 'LAURA.RODRIGUEZ@sakilacustomer.org', 26, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (23, 2, 'SARAH', 'LEWIS', 'SARAH.LEWIS@sakilacustomer.org', 27, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (24, 2, 'KIMBERLY', 'LEE', 'KIMBERLY.LEE@sakilacustomer.org', 28, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (25, 1, 'DEBORAH', 'WALKER', 'DEBORAH.WALKER@sakilacustomer.org', 29, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (26, 2, 'JESSICA', 'HALL', 'JESSICA.HALL@sakilacustomer.org', 30, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (27, 2, 'SHIRLEY', 'ALLEN', 'SHIRLEY.ALLEN@sakilacustomer.org', 31, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (28, 1, 'CYNTHIA', 'YOUNG', 'CYNTHIA.YOUNG@sakilacustomer.org', 32, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (29, 2, 'ANGELA', 'HERNANDEZ', 'ANGELA.HERNANDEZ@sakilacustomer.org', 33, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (30, 1, 'MELISSA', 'KING', 'MELISSA.KING@sakilacustomer.org', 34, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (31, 2, 'BRENDA', 'WRIGHT', 'BRENDA.WRIGHT@sakilacustomer.org', 35, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (32, 1, 'AMY', 'LOPEZ', 'AMY.LOPEZ@sakilacustomer.org', 36, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (33, 2, 'ANNA', 'HILL', 'ANNA.HILL@sakilacustomer.org', 37, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (34, 2, 'REBECCA', 'SCOTT', 'REBECCA.SCOTT@sakilacustomer.org', 38, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (35, 2, 'VIRGINIA', 'GREEN', 'VIRGINIA.GREEN@sakilacustomer.org', 39, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (36, 2, 'KATHLEEN', 'ADAMS', 'KATHLEEN.ADAMS@sakilacustomer.org', 40, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (37, 1, 'PAMELA', 'BAKER', 'PAMELA.BAKER@sakilacustomer.org', 41, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (38, 1, 'MARTHA', 'GONZALEZ', 'MARTHA.GONZALEZ@sakilacustomer.org', 42, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (39, 1, 'DEBRA', 'NELSON', 'DEBRA.NELSON@sakilacustomer.org', 43, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (40, 2, 'AMANDA', 'CARTER', 'AMANDA.CARTER@sakilacustomer.org', 44, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (41, 1, 'STEPHANIE', 'MITCHELL', 'STEPHANIE.MITCHELL@sakilacustomer.org', 45, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (42, 2, 'CAROLYN', 'PEREZ', 'CAROLYN.PEREZ@sakilacustomer.org', 46, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (43, 2, 'CHRISTINE', 'ROBERTS', 'CHRISTINE.ROBERTS@sakilacustomer.org', 47, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (44, 1, 'MARIE', 'TURNER', 'MARIE.TURNER@sakilacustomer.org', 48, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (45, 1, 'JANET', 'PHILLIPS', 'JANET.PHILLIPS@sakilacustomer.org', 49, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (46, 2, 'CATHERINE', 'CAMPBELL', 'CATHERINE.CAMPBELL@sakilacustomer.org', 50, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (47, 1, 'FRANCES', 'PARKER', 'FRANCES.PARKER@sakilacustomer.org', 51, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (48, 1, 'ANN', 'EVANS', 'ANN.EVANS@sakilacustomer.org', 52, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (49, 2, 'JOYCE', 'EDWARDS', 'JOYCE.EDWARDS@sakilacustomer.org', 53, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (50, 1, 'DIANE', 'COLLINS', 'DIANE.COLLINS@sakilacustomer.org', 54, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (51, 1, 'ALICE', 'STEWART', 'ALICE.STEWART@sakilacustomer.org', 55, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (52, 1, 'JULIE', 'SANCHEZ', 'JULIE.SANCHEZ@sakilacustomer.org', 56, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (53, 1, 'HEATHER', 'MORRIS', 'HEATHER.MORRIS@sakilacustomer.org', 57, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (54, 1, 'TERESA', 'ROGERS', 'TERESA.ROGERS@sakilacustomer.org', 58, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (55, 2, 'DORIS', 'REED', 'DORIS.REED@sakilacustomer.org', 59, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (56, 1, 'GLORIA', 'COOK', 'GLORIA.COOK@sakilacustomer.org', 60, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (57, 2, 'EVELYN', 'MORGAN', 'EVELYN.MORGAN@sakilacustomer.org', 61, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (58, 1, 'JEAN', 'BELL', 'JEAN.BELL@sakilacustomer.org', 62, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (59, 1, 'CHERYL', 'MURPHY', 'CHERYL.MURPHY@sakilacustomer.org', 63, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (60, 1, 'MILDRED', 'BAILEY', 'MILDRED.BAILEY@sakilacustomer.org', 64, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (61, 2, 'KATHERINE', 'RIVERA', 'KATHERINE.RIVERA@sakilacustomer.org', 65, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (62, 1, 'JOAN', 'COOPER', 'JOAN.COOPER@sakilacustomer.org', 66, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (63, 1, 'ASHLEY', 'RICHARDSON', 'ASHLEY.RICHARDSON@sakilacustomer.org', 67, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (65, 2, 'ROSE', 'HOWARD', 'ROSE.HOWARD@sakilacustomer.org', 69, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (66, 2, 'JANICE', 'WARD', 'JANICE.WARD@sakilacustomer.org', 70, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (67, 1, 'KELLY', 'TORRES', 'KELLY.TORRES@sakilacustomer.org', 71, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (68, 1, 'NICOLE', 'PETERSON', 'NICOLE.PETERSON@sakilacustomer.org', 72, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (69, 2, 'JUDY', 'GRAY', 'JUDY.GRAY@sakilacustomer.org', 73, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (70, 2, 'CHRISTINA', 'RAMIREZ', 'CHRISTINA.RAMIREZ@sakilacustomer.org', 74, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (71, 1, 'KATHY', 'JAMES', 'KATHY.JAMES@sakilacustomer.org', 75, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (72, 2, 'THERESA', 'WATSON', 'THERESA.WATSON@sakilacustomer.org', 76, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (73, 2, 'BEVERLY', 'BROOKS', 'BEVERLY.BROOKS@sakilacustomer.org', 77, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (74, 1, 'DENISE', 'KELLY', 'DENISE.KELLY@sakilacustomer.org', 78, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (75, 2, 'TAMMY', 'SANDERS', 'TAMMY.SANDERS@sakilacustomer.org', 79, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (76, 2, 'IRENE', 'PRICE', 'IRENE.PRICE@sakilacustomer.org', 80, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (77, 2, 'JANE', 'BENNETT', 'JANE.BENNETT@sakilacustomer.org', 81, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (78, 1, 'LORI', 'WOOD', 'LORI.WOOD@sakilacustomer.org', 82, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (79, 1, 'RACHEL', 'BARNES', 'RACHEL.BARNES@sakilacustomer.org', 83, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (80, 1, 'MARILYN', 'ROSS', 'MARILYN.ROSS@sakilacustomer.org', 84, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (81, 1, 'ANDREA', 'HENDERSON', 'ANDREA.HENDERSON@sakilacustomer.org', 85, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (82, 1, 'KATHRYN', 'COLEMAN', 'KATHRYN.COLEMAN@sakilacustomer.org', 86, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (83, 1, 'LOUISE', 'JENKINS', 'LOUISE.JENKINS@sakilacustomer.org', 87, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (84, 2, 'SARA', 'PERRY', 'SARA.PERRY@sakilacustomer.org', 88, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (85, 2, 'ANNE', 'POWELL', 'ANNE.POWELL@sakilacustomer.org', 89, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (86, 2, 'JACQUELINE', 'LONG', 'JACQUELINE.LONG@sakilacustomer.org', 90, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (87, 1, 'WANDA', 'PATTERSON', 'WANDA.PATTERSON@sakilacustomer.org', 91, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (88, 2, 'BONNIE', 'HUGHES', 'BONNIE.HUGHES@sakilacustomer.org', 92, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (89, 1, 'JULIA', 'FLORES', 'JULIA.FLORES@sakilacustomer.org', 93, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (90, 2, 'RUBY', 'WASHINGTON', 'RUBY.WASHINGTON@sakilacustomer.org', 94, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (91, 2, 'LOIS', 'BUTLER', 'LOIS.BUTLER@sakilacustomer.org', 95, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (92, 2, 'TINA', 'SIMMONS', 'TINA.SIMMONS@sakilacustomer.org', 96, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (93, 1, 'PHYLLIS', 'FOSTER', 'PHYLLIS.FOSTER@sakilacustomer.org', 97, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (94, 1, 'NORMA', 'GONZALES', 'NORMA.GONZALES@sakilacustomer.org', 98, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (95, 2, 'PAULA', 'BRYANT', 'PAULA.BRYANT@sakilacustomer.org', 99, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (96, 1, 'DIANA', 'ALEXANDER', 'DIANA.ALEXANDER@sakilacustomer.org', 100, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (97, 2, 'ANNIE', 'RUSSELL', 'ANNIE.RUSSELL@sakilacustomer.org', 101, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (98, 1, 'LILLIAN', 'GRIFFIN', 'LILLIAN.GRIFFIN@sakilacustomer.org', 102, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (99, 2, 'EMILY', 'DIAZ', 'EMILY.DIAZ@sakilacustomer.org', 103, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (100, 1, 'ROBIN', 'HAYES', 'ROBIN.HAYES@sakilacustomer.org', 104, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (101, 1, 'PEGGY', 'MYERS', 'PEGGY.MYERS@sakilacustomer.org', 105, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (102, 1, 'CRYSTAL', 'FORD', 'CRYSTAL.FORD@sakilacustomer.org', 106, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (103, 1, 'GLADYS', 'HAMILTON', 'GLADYS.HAMILTON@sakilacustomer.org', 107, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (104, 1, 'RITA', 'GRAHAM', 'RITA.GRAHAM@sakilacustomer.org', 108, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (105, 1, 'DAWN', 'SULLIVAN', 'DAWN.SULLIVAN@sakilacustomer.org', 109, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (106, 1, 'CONNIE', 'WALLACE', 'CONNIE.WALLACE@sakilacustomer.org', 110, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (107, 1, 'FLORENCE', 'WOODS', 'FLORENCE.WOODS@sakilacustomer.org', 111, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (108, 1, 'TRACY', 'COLE', 'TRACY.COLE@sakilacustomer.org', 112, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (109, 2, 'EDNA', 'WEST', 'EDNA.WEST@sakilacustomer.org', 113, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (110, 2, 'TIFFANY', 'JORDAN', 'TIFFANY.JORDAN@sakilacustomer.org', 114, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (111, 1, 'CARMEN', 'OWENS', 'CARMEN.OWENS@sakilacustomer.org', 115, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (112, 2, 'ROSA', 'REYNOLDS', 'ROSA.REYNOLDS@sakilacustomer.org', 116, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (113, 2, 'CINDY', 'FISHER', 'CINDY.FISHER@sakilacustomer.org', 117, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (114, 2, 'GRACE', 'ELLIS', 'GRACE.ELLIS@sakilacustomer.org', 118, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (115, 1, 'WENDY', 'HARRISON', 'WENDY.HARRISON@sakilacustomer.org', 119, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (116, 1, 'VICTORIA', 'GIBSON', 'VICTORIA.GIBSON@sakilacustomer.org', 120, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (117, 1, 'EDITH', 'MCDONALD', 'EDITH.MCDONALD@sakilacustomer.org', 121, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (118, 1, 'KIM', 'CRUZ', 'KIM.CRUZ@sakilacustomer.org', 122, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (119, 1, 'SHERRY', 'MARSHALL', 'SHERRY.MARSHALL@sakilacustomer.org', 123, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (120, 2, 'SYLVIA', 'ORTIZ', 'SYLVIA.ORTIZ@sakilacustomer.org', 124, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (121, 1, 'JOSEPHINE', 'GOMEZ', 'JOSEPHINE.GOMEZ@sakilacustomer.org', 125, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (122, 1, 'THELMA', 'MURRAY', 'THELMA.MURRAY@sakilacustomer.org', 126, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (123, 2, 'SHANNON', 'FREEMAN', 'SHANNON.FREEMAN@sakilacustomer.org', 127, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (125, 1, 'ETHEL', 'WEBB', 'ETHEL.WEBB@sakilacustomer.org', 129, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (126, 1, 'ELLEN', 'SIMPSON', 'ELLEN.SIMPSON@sakilacustomer.org', 130, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (127, 2, 'ELAINE', 'STEVENS', 'ELAINE.STEVENS@sakilacustomer.org', 131, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (128, 1, 'MARJORIE', 'TUCKER', 'MARJORIE.TUCKER@sakilacustomer.org', 132, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (129, 1, 'CARRIE', 'PORTER', 'CARRIE.PORTER@sakilacustomer.org', 133, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (130, 1, 'CHARLOTTE', 'HUNTER', 'CHARLOTTE.HUNTER@sakilacustomer.org', 134, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (131, 2, 'MONICA', 'HICKS', 'MONICA.HICKS@sakilacustomer.org', 135, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (132, 2, 'ESTHER', 'CRAWFORD', 'ESTHER.CRAWFORD@sakilacustomer.org', 136, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (133, 1, 'PAULINE', 'HENRY', 'PAULINE.HENRY@sakilacustomer.org', 137, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (134, 1, 'EMMA', 'BOYD', 'EMMA.BOYD@sakilacustomer.org', 138, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (135, 2, 'JUANITA', 'MASON', 'JUANITA.MASON@sakilacustomer.org', 139, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (136, 2, 'ANITA', 'MORALES', 'ANITA.MORALES@sakilacustomer.org', 140, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (137, 2, 'RHONDA', 'KENNEDY', 'RHONDA.KENNEDY@sakilacustomer.org', 141, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (138, 1, 'HAZEL', 'WARREN', 'HAZEL.WARREN@sakilacustomer.org', 142, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (139, 1, 'AMBER', 'DIXON', 'AMBER.DIXON@sakilacustomer.org', 143, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (140, 1, 'EVA', 'RAMOS', 'EVA.RAMOS@sakilacustomer.org', 144, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (141, 1, 'DEBBIE', 'REYES', 'DEBBIE.REYES@sakilacustomer.org', 145, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (142, 1, 'APRIL', 'BURNS', 'APRIL.BURNS@sakilacustomer.org', 146, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (143, 1, 'LESLIE', 'GORDON', 'LESLIE.GORDON@sakilacustomer.org', 147, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (144, 1, 'CLARA', 'SHAW', 'CLARA.SHAW@sakilacustomer.org', 148, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (145, 1, 'LUCILLE', 'HOLMES', 'LUCILLE.HOLMES@sakilacustomer.org', 149, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (146, 1, 'JAMIE', 'RICE', 'JAMIE.RICE@sakilacustomer.org', 150, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (147, 2, 'JOANNE', 'ROBERTSON', 'JOANNE.ROBERTSON@sakilacustomer.org', 151, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (148, 1, 'ELEANOR', 'HUNT', 'ELEANOR.HUNT@sakilacustomer.org', 152, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (149, 1, 'VALERIE', 'BLACK', 'VALERIE.BLACK@sakilacustomer.org', 153, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (150, 2, 'DANIELLE', 'DANIELS', 'DANIELLE.DANIELS@sakilacustomer.org', 154, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (151, 2, 'MEGAN', 'PALMER', 'MEGAN.PALMER@sakilacustomer.org', 155, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (152, 1, 'ALICIA', 'MILLS', 'ALICIA.MILLS@sakilacustomer.org', 156, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (153, 2, 'SUZANNE', 'NICHOLS', 'SUZANNE.NICHOLS@sakilacustomer.org', 157, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (154, 2, 'MICHELE', 'GRANT', 'MICHELE.GRANT@sakilacustomer.org', 158, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (155, 1, 'GAIL', 'KNIGHT', 'GAIL.KNIGHT@sakilacustomer.org', 159, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (156, 1, 'BERTHA', 'FERGUSON', 'BERTHA.FERGUSON@sakilacustomer.org', 160, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (157, 2, 'DARLENE', 'ROSE', 'DARLENE.ROSE@sakilacustomer.org', 161, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (158, 1, 'VERONICA', 'STONE', 'VERONICA.STONE@sakilacustomer.org', 162, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (159, 1, 'JILL', 'HAWKINS', 'JILL.HAWKINS@sakilacustomer.org', 163, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (160, 2, 'ERIN', 'DUNN', 'ERIN.DUNN@sakilacustomer.org', 164, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (161, 1, 'GERALDINE', 'PERKINS', 'GERALDINE.PERKINS@sakilacustomer.org', 165, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (162, 2, 'LAUREN', 'HUDSON', 'LAUREN.HUDSON@sakilacustomer.org', 166, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (163, 1, 'CATHY', 'SPENCER', 'CATHY.SPENCER@sakilacustomer.org', 167, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (164, 2, 'JOANN', 'GARDNER', 'JOANN.GARDNER@sakilacustomer.org', 168, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (165, 2, 'LORRAINE', 'STEPHENS', 'LORRAINE.STEPHENS@sakilacustomer.org', 169, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (166, 1, 'LYNN', 'PAYNE', 'LYNN.PAYNE@sakilacustomer.org', 170, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (167, 2, 'SALLY', 'PIERCE', 'SALLY.PIERCE@sakilacustomer.org', 171, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (168, 1, 'REGINA', 'BERRY', 'REGINA.BERRY@sakilacustomer.org', 172, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (170, 1, 'BEATRICE', 'ARNOLD', 'BEATRICE.ARNOLD@sakilacustomer.org', 174, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (171, 2, 'DOLORES', 'WAGNER', 'DOLORES.WAGNER@sakilacustomer.org', 175, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (172, 1, 'BERNICE', 'WILLIS', 'BERNICE.WILLIS@sakilacustomer.org', 176, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (173, 1, 'AUDREY', 'RAY', 'AUDREY.RAY@sakilacustomer.org', 177, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (174, 2, 'YVONNE', 'WATKINS', 'YVONNE.WATKINS@sakilacustomer.org', 178, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (175, 1, 'ANNETTE', 'OLSON', 'ANNETTE.OLSON@sakilacustomer.org', 179, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (176, 1, 'JUNE', 'CARROLL', 'JUNE.CARROLL@sakilacustomer.org', 180, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (177, 2, 'SAMANTHA', 'DUNCAN', 'SAMANTHA.DUNCAN@sakilacustomer.org', 181, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (178, 2, 'MARION', 'SNYDER', 'MARION.SNYDER@sakilacustomer.org', 182, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (179, 1, 'DANA', 'HART', 'DANA.HART@sakilacustomer.org', 183, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (180, 2, 'STACY', 'CUNNINGHAM', 'STACY.CUNNINGHAM@sakilacustomer.org', 184, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (181, 2, 'ANA', 'BRADLEY', 'ANA.BRADLEY@sakilacustomer.org', 185, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (182, 1, 'RENEE', 'LANE', 'RENEE.LANE@sakilacustomer.org', 186, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (183, 2, 'IDA', 'ANDREWS', 'IDA.ANDREWS@sakilacustomer.org', 187, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (184, 1, 'VIVIAN', 'RUIZ', 'VIVIAN.RUIZ@sakilacustomer.org', 188, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (185, 1, 'ROBERTA', 'HARPER', 'ROBERTA.HARPER@sakilacustomer.org', 189, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (186, 2, 'HOLLY', 'FOX', 'HOLLY.FOX@sakilacustomer.org', 190, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (187, 2, 'BRITTANY', 'RILEY', 'BRITTANY.RILEY@sakilacustomer.org', 191, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (188, 1, 'MELANIE', 'ARMSTRONG', 'MELANIE.ARMSTRONG@sakilacustomer.org', 192, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (189, 1, 'LORETTA', 'CARPENTER', 'LORETTA.CARPENTER@sakilacustomer.org', 193, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (190, 2, 'YOLANDA', 'WEAVER', 'YOLANDA.WEAVER@sakilacustomer.org', 194, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (191, 1, 'JEANETTE', 'GREENE', 'JEANETTE.GREENE@sakilacustomer.org', 195, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (192, 1, 'LAURIE', 'LAWRENCE', 'LAURIE.LAWRENCE@sakilacustomer.org', 196, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (193, 2, 'KATIE', 'ELLIOTT', 'KATIE.ELLIOTT@sakilacustomer.org', 197, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (194, 2, 'KRISTEN', 'CHAVEZ', 'KRISTEN.CHAVEZ@sakilacustomer.org', 198, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (195, 1, 'VANESSA', 'SIMS', 'VANESSA.SIMS@sakilacustomer.org', 199, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (196, 1, 'ALMA', 'AUSTIN', 'ALMA.AUSTIN@sakilacustomer.org', 200, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (197, 2, 'SUE', 'PETERS', 'SUE.PETERS@sakilacustomer.org', 201, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (198, 2, 'ELSIE', 'KELLEY', 'ELSIE.KELLEY@sakilacustomer.org', 202, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (199, 2, 'BETH', 'FRANKLIN', 'BETH.FRANKLIN@sakilacustomer.org', 203, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (200, 2, 'JEANNE', 'LAWSON', 'JEANNE.LAWSON@sakilacustomer.org', 204, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (201, 1, 'VICKI', 'FIELDS', 'VICKI.FIELDS@sakilacustomer.org', 205, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (202, 2, 'CARLA', 'GUTIERREZ', 'CARLA.GUTIERREZ@sakilacustomer.org', 206, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (203, 1, 'TARA', 'RYAN', 'TARA.RYAN@sakilacustomer.org', 207, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (204, 1, 'ROSEMARY', 'SCHMIDT', 'ROSEMARY.SCHMIDT@sakilacustomer.org', 208, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (205, 2, 'EILEEN', 'CARR', 'EILEEN.CARR@sakilacustomer.org', 209, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (206, 1, 'TERRI', 'VASQUEZ', 'TERRI.VASQUEZ@sakilacustomer.org', 210, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (207, 1, 'GERTRUDE', 'CASTILLO', 'GERTRUDE.CASTILLO@sakilacustomer.org', 211, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (208, 1, 'LUCY', 'WHEELER', 'LUCY.WHEELER@sakilacustomer.org', 212, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (209, 2, 'TONYA', 'CHAPMAN', 'TONYA.CHAPMAN@sakilacustomer.org', 213, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (210, 2, 'ELLA', 'OLIVER', 'ELLA.OLIVER@sakilacustomer.org', 214, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (211, 1, 'STACEY', 'MONTGOMERY', 'STACEY.MONTGOMERY@sakilacustomer.org', 215, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (212, 2, 'WILMA', 'RICHARDS', 'WILMA.RICHARDS@sakilacustomer.org', 216, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (213, 1, 'GINA', 'WILLIAMSON', 'GINA.WILLIAMSON@sakilacustomer.org', 217, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (214, 1, 'KRISTIN', 'JOHNSTON', 'KRISTIN.JOHNSTON@sakilacustomer.org', 218, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (215, 2, 'JESSIE', 'BANKS', 'JESSIE.BANKS@sakilacustomer.org', 219, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (216, 1, 'NATALIE', 'MEYER', 'NATALIE.MEYER@sakilacustomer.org', 220, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (217, 2, 'AGNES', 'BISHOP', 'AGNES.BISHOP@sakilacustomer.org', 221, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (218, 1, 'VERA', 'MCCOY', 'VERA.MCCOY@sakilacustomer.org', 222, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (219, 2, 'WILLIE', 'HOWELL', 'WILLIE.HOWELL@sakilacustomer.org', 223, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (220, 2, 'CHARLENE', 'ALVAREZ', 'CHARLENE.ALVAREZ@sakilacustomer.org', 224, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (221, 1, 'BESSIE', 'MORRISON', 'BESSIE.MORRISON@sakilacustomer.org', 225, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (222, 2, 'DELORES', 'HANSEN', 'DELORES.HANSEN@sakilacustomer.org', 226, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (223, 1, 'MELINDA', 'FERNANDEZ', 'MELINDA.FERNANDEZ@sakilacustomer.org', 227, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (224, 2, 'PEARL', 'GARZA', 'PEARL.GARZA@sakilacustomer.org', 228, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (225, 1, 'ARLENE', 'HARVEY', 'ARLENE.HARVEY@sakilacustomer.org', 229, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (226, 2, 'MAUREEN', 'LITTLE', 'MAUREEN.LITTLE@sakilacustomer.org', 230, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (227, 1, 'COLLEEN', 'BURTON', 'COLLEEN.BURTON@sakilacustomer.org', 231, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (228, 2, 'ALLISON', 'STANLEY', 'ALLISON.STANLEY@sakilacustomer.org', 232, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (229, 1, 'TAMARA', 'NGUYEN', 'TAMARA.NGUYEN@sakilacustomer.org', 233, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (230, 2, 'JOY', 'GEORGE', 'JOY.GEORGE@sakilacustomer.org', 234, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (231, 1, 'GEORGIA', 'JACOBS', 'GEORGIA.JACOBS@sakilacustomer.org', 235, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (232, 2, 'CONSTANCE', 'REID', 'CONSTANCE.REID@sakilacustomer.org', 236, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (233, 2, 'LILLIE', 'KIM', 'LILLIE.KIM@sakilacustomer.org', 237, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (234, 1, 'CLAUDIA', 'FULLER', 'CLAUDIA.FULLER@sakilacustomer.org', 238, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (235, 1, 'JACKIE', 'LYNCH', 'JACKIE.LYNCH@sakilacustomer.org', 239, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (236, 1, 'MARCIA', 'DEAN', 'MARCIA.DEAN@sakilacustomer.org', 240, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (237, 1, 'TANYA', 'GILBERT', 'TANYA.GILBERT@sakilacustomer.org', 241, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (238, 1, 'NELLIE', 'GARRETT', 'NELLIE.GARRETT@sakilacustomer.org', 242, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (239, 2, 'MINNIE', 'ROMERO', 'MINNIE.ROMERO@sakilacustomer.org', 243, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (240, 1, 'MARLENE', 'WELCH', 'MARLENE.WELCH@sakilacustomer.org', 244, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (242, 1, 'GLENDA', 'FRAZIER', 'GLENDA.FRAZIER@sakilacustomer.org', 246, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (243, 1, 'LYDIA', 'BURKE', 'LYDIA.BURKE@sakilacustomer.org', 247, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (244, 2, 'VIOLA', 'HANSON', 'VIOLA.HANSON@sakilacustomer.org', 248, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (245, 1, 'COURTNEY', 'DAY', 'COURTNEY.DAY@sakilacustomer.org', 249, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (246, 1, 'MARIAN', 'MENDOZA', 'MARIAN.MENDOZA@sakilacustomer.org', 250, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (247, 1, 'STELLA', 'MORENO', 'STELLA.MORENO@sakilacustomer.org', 251, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (248, 1, 'CAROLINE', 'BOWMAN', 'CAROLINE.BOWMAN@sakilacustomer.org', 252, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (249, 2, 'DORA', 'MEDINA', 'DORA.MEDINA@sakilacustomer.org', 253, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (250, 2, 'JO', 'FOWLER', 'JO.FOWLER@sakilacustomer.org', 254, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (251, 2, 'VICKIE', 'BREWER', 'VICKIE.BREWER@sakilacustomer.org', 255, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (252, 2, 'MATTIE', 'HOFFMAN', 'MATTIE.HOFFMAN@sakilacustomer.org', 256, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (253, 1, 'TERRY', 'CARLSON', 'TERRY.CARLSON@sakilacustomer.org', 258, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (254, 2, 'MAXINE', 'SILVA', 'MAXINE.SILVA@sakilacustomer.org', 259, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (255, 2, 'IRMA', 'PEARSON', 'IRMA.PEARSON@sakilacustomer.org', 260, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (256, 2, 'MABEL', 'HOLLAND', 'MABEL.HOLLAND@sakilacustomer.org', 261, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (257, 2, 'MARSHA', 'DOUGLAS', 'MARSHA.DOUGLAS@sakilacustomer.org', 262, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (258, 1, 'MYRTLE', 'FLEMING', 'MYRTLE.FLEMING@sakilacustomer.org', 263, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (259, 2, 'LENA', 'JENSEN', 'LENA.JENSEN@sakilacustomer.org', 264, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (260, 1, 'CHRISTY', 'VARGAS', 'CHRISTY.VARGAS@sakilacustomer.org', 265, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (261, 1, 'DEANNA', 'BYRD', 'DEANNA.BYRD@sakilacustomer.org', 266, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (262, 2, 'PATSY', 'DAVIDSON', 'PATSY.DAVIDSON@sakilacustomer.org', 267, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (263, 1, 'HILDA', 'HOPKINS', 'HILDA.HOPKINS@sakilacustomer.org', 268, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (264, 1, 'GWENDOLYN', 'MAY', 'GWENDOLYN.MAY@sakilacustomer.org', 269, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (265, 2, 'JENNIE', 'TERRY', 'JENNIE.TERRY@sakilacustomer.org', 270, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (266, 2, 'NORA', 'HERRERA', 'NORA.HERRERA@sakilacustomer.org', 271, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (267, 1, 'MARGIE', 'WADE', 'MARGIE.WADE@sakilacustomer.org', 272, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (268, 1, 'NINA', 'SOTO', 'NINA.SOTO@sakilacustomer.org', 273, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (269, 1, 'CASSANDRA', 'WALTERS', 'CASSANDRA.WALTERS@sakilacustomer.org', 274, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (270, 1, 'LEAH', 'CURTIS', 'LEAH.CURTIS@sakilacustomer.org', 275, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (272, 1, 'KAY', 'CALDWELL', 'KAY.CALDWELL@sakilacustomer.org', 277, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (273, 2, 'PRISCILLA', 'LOWE', 'PRISCILLA.LOWE@sakilacustomer.org', 278, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (274, 1, 'NAOMI', 'JENNINGS', 'NAOMI.JENNINGS@sakilacustomer.org', 279, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (275, 2, 'CAROLE', 'BARNETT', 'CAROLE.BARNETT@sakilacustomer.org', 280, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (276, 1, 'BRANDY', 'GRAVES', 'BRANDY.GRAVES@sakilacustomer.org', 281, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (277, 2, 'OLGA', 'JIMENEZ', 'OLGA.JIMENEZ@sakilacustomer.org', 282, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (278, 2, 'BILLIE', 'HORTON', 'BILLIE.HORTON@sakilacustomer.org', 283, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (279, 2, 'DIANNE', 'SHELTON', 'DIANNE.SHELTON@sakilacustomer.org', 284, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (280, 2, 'TRACEY', 'BARRETT', 'TRACEY.BARRETT@sakilacustomer.org', 285, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (281, 2, 'LEONA', 'OBRIEN', 'LEONA.OBRIEN@sakilacustomer.org', 286, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (282, 2, 'JENNY', 'CASTRO', 'JENNY.CASTRO@sakilacustomer.org', 287, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (283, 1, 'FELICIA', 'SUTTON', 'FELICIA.SUTTON@sakilacustomer.org', 288, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (284, 1, 'SONIA', 'GREGORY', 'SONIA.GREGORY@sakilacustomer.org', 289, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (285, 1, 'MIRIAM', 'MCKINNEY', 'MIRIAM.MCKINNEY@sakilacustomer.org', 290, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (286, 1, 'VELMA', 'LUCAS', 'VELMA.LUCAS@sakilacustomer.org', 291, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (287, 2, 'BECKY', 'MILES', 'BECKY.MILES@sakilacustomer.org', 292, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (288, 1, 'BOBBIE', 'CRAIG', 'BOBBIE.CRAIG@sakilacustomer.org', 293, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (289, 1, 'VIOLET', 'RODRIQUEZ', 'VIOLET.RODRIQUEZ@sakilacustomer.org', 294, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (290, 1, 'KRISTINA', 'CHAMBERS', 'KRISTINA.CHAMBERS@sakilacustomer.org', 295, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (291, 1, 'TONI', 'HOLT', 'TONI.HOLT@sakilacustomer.org', 296, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (292, 2, 'MISTY', 'LAMBERT', 'MISTY.LAMBERT@sakilacustomer.org', 297, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (293, 2, 'MAE', 'FLETCHER', 'MAE.FLETCHER@sakilacustomer.org', 298, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (294, 2, 'SHELLY', 'WATTS', 'SHELLY.WATTS@sakilacustomer.org', 299, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (295, 1, 'DAISY', 'BATES', 'DAISY.BATES@sakilacustomer.org', 300, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (296, 2, 'RAMONA', 'HALE', 'RAMONA.HALE@sakilacustomer.org', 301, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (297, 1, 'SHERRI', 'RHODES', 'SHERRI.RHODES@sakilacustomer.org', 302, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (298, 1, 'ERIKA', 'PENA', 'ERIKA.PENA@sakilacustomer.org', 303, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (299, 2, 'JAMES', 'GANNON', 'JAMES.GANNON@sakilacustomer.org', 304, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (300, 1, 'JOHN', 'FARNSWORTH', 'JOHN.FARNSWORTH@sakilacustomer.org', 305, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (301, 2, 'ROBERT', 'BAUGHMAN', 'ROBERT.BAUGHMAN@sakilacustomer.org', 306, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (302, 1, 'MICHAEL', 'SILVERMAN', 'MICHAEL.SILVERMAN@sakilacustomer.org', 307, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (303, 2, 'WILLIAM', 'SATTERFIELD', 'WILLIAM.SATTERFIELD@sakilacustomer.org', 308, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (304, 2, 'DAVID', 'ROYAL', 'DAVID.ROYAL@sakilacustomer.org', 309, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (305, 1, 'RICHARD', 'MCCRARY', 'RICHARD.MCCRARY@sakilacustomer.org', 310, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
# ...
#  (497, 2, 'GILBERT', 'SLEDGE', 'GILBERT.SLEDGE@sakilacustomer.org', 502, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (498, 1, 'GENE', 'SANBORN', 'GENE.SANBORN@sakilacustomer.org', 503, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (499, 2, 'MARC', 'OUTLAW', 'MARC.OUTLAW@sakilacustomer.org', 504, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (500, 1, 'REGINALD', 'KINDER', 'REGINALD.KINDER@sakilacustomer.org', 505, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (501, 1, 'RUBEN', 'GEARY', 'RUBEN.GEARY@sakilacustomer.org', 506, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (502, 1, 'BRETT', 'CORNWELL', 'BRETT.CORNWELL@sakilacustomer.org', 507, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (503, 1, 'ANGEL', 'BARCLAY', 'ANGEL.BARCLAY@sakilacustomer.org', 508, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (504, 1, 'NATHANIEL', 'ADAM', 'NATHANIEL.ADAM@sakilacustomer.org', 509, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (505, 1, 'RAFAEL', 'ABNEY', 'RAFAEL.ABNEY@sakilacustomer.org', 510, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (506, 2, 'LESLIE', 'SEWARD', 'LESLIE.SEWARD@sakilacustomer.org', 511, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (507, 2, 'EDGAR', 'RHOADS', 'EDGAR.RHOADS@sakilacustomer.org', 512, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (508, 2, 'MILTON', 'HOWLAND', 'MILTON.HOWLAND@sakilacustomer.org', 513, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (509, 1, 'RAUL', 'FORTIER', 'RAUL.FORTIER@sakilacustomer.org', 514, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (511, 1, 'CHESTER', 'BENNER', 'CHESTER.BENNER@sakilacustomer.org', 516, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (512, 1, 'CECIL', 'VINES', 'CECIL.VINES@sakilacustomer.org', 517, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (513, 2, 'DUANE', 'TUBBS', 'DUANE.TUBBS@sakilacustomer.org', 519, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (514, 2, 'FRANKLIN', 'TROUTMAN', 'FRANKLIN.TROUTMAN@sakilacustomer.org', 520, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (515, 1, 'ANDRE', 'RAPP', 'ANDRE.RAPP@sakilacustomer.org', 521, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (516, 2, 'ELMER', 'NOE', 'ELMER.NOE@sakilacustomer.org', 522, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (517, 2, 'BRAD', 'MCCURDY', 'BRAD.MCCURDY@sakilacustomer.org', 523, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (518, 1, 'GABRIEL', 'HARDER', 'GABRIEL.HARDER@sakilacustomer.org', 524, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (519, 2, 'RON', 'DELUCA', 'RON.DELUCA@sakilacustomer.org', 525, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (520, 2, 'MITCHELL', 'WESTMORELAND', 'MITCHELL.WESTMORELAND@sakilacustomer.org', 526, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (521, 2, 'ROLAND', 'SOUTH', 'ROLAND.SOUTH@sakilacustomer.org', 527, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (522, 2, 'ARNOLD', 'HAVENS', 'ARNOLD.HAVENS@sakilacustomer.org', 528, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (523, 1, 'HARVEY', 'GUAJARDO', 'HARVEY.GUAJARDO@sakilacustomer.org', 529, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (524, 1, 'JARED', 'ELY', 'JARED.ELY@sakilacustomer.org', 530, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (525, 2, 'ADRIAN', 'CLARY', 'ADRIAN.CLARY@sakilacustomer.org', 531, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (526, 2, 'KARL', 'SEAL', 'KARL.SEAL@sakilacustomer.org', 532, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (527, 1, 'CORY', 'MEEHAN', 'CORY.MEEHAN@sakilacustomer.org', 533, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (528, 1, 'CLAUDE', 'HERZOG', 'CLAUDE.HERZOG@sakilacustomer.org', 534, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (529, 2, 'ERIK', 'GUILLEN', 'ERIK.GUILLEN@sakilacustomer.org', 535, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (530, 2, 'DARRYL', 'ASHCRAFT', 'DARRYL.ASHCRAFT@sakilacustomer.org', 536, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (531, 2, 'JAMIE', 'WAUGH', 'JAMIE.WAUGH@sakilacustomer.org', 537, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (532, 2, 'NEIL', 'RENNER', 'NEIL.RENNER@sakilacustomer.org', 538, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (533, 1, 'JESSIE', 'MILAM', 'JESSIE.MILAM@sakilacustomer.org', 539, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (535, 1, 'JAVIER', 'ELROD', 'JAVIER.ELROD@sakilacustomer.org', 541, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (536, 2, 'FERNANDO', 'CHURCHILL', 'FERNANDO.CHURCHILL@sakilacustomer.org', 542, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (537, 2, 'CLINTON', 'BUFORD', 'CLINTON.BUFORD@sakilacustomer.org', 543, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (538, 2, 'TED', 'BREAUX', 'TED.BREAUX@sakilacustomer.org', 544, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (539, 1, 'MATHEW', 'BOLIN', 'MATHEW.BOLIN@sakilacustomer.org', 545, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (540, 1, 'TYRONE', 'ASHER', 'TYRONE.ASHER@sakilacustomer.org', 546, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (541, 2, 'DARREN', 'WINDHAM', 'DARREN.WINDHAM@sakilacustomer.org', 547, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (542, 2, 'LONNIE', 'TIRADO', 'LONNIE.TIRADO@sakilacustomer.org', 548, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (543, 1, 'LANCE', 'PEMBERTON', 'LANCE.PEMBERTON@sakilacustomer.org', 549, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (544, 2, 'CODY', 'NOLEN', 'CODY.NOLEN@sakilacustomer.org', 550, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (545, 2, 'JULIO', 'NOLAND', 'JULIO.NOLAND@sakilacustomer.org', 551, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (546, 1, 'KELLY', 'KNOTT', 'KELLY.KNOTT@sakilacustomer.org', 552, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (547, 1, 'KURT', 'EMMONS', 'KURT.EMMONS@sakilacustomer.org', 553, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (548, 1, 'ALLAN', 'CORNISH', 'ALLAN.CORNISH@sakilacustomer.org', 554, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (549, 1, 'NELSON', 'CHRISTENSON', 'NELSON.CHRISTENSON@sakilacustomer.org', 555, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (550, 2, 'GUY', 'BROWNLEE', 'GUY.BROWNLEE@sakilacustomer.org', 556, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (551, 2, 'CLAYTON', 'BARBEE', 'CLAYTON.BARBEE@sakilacustomer.org', 557, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (552, 2, 'HUGH', 'WALDROP', 'HUGH.WALDROP@sakilacustomer.org', 558, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (553, 1, 'MAX', 'PITT', 'MAX.PITT@sakilacustomer.org', 559, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (554, 1, 'DWAYNE', 'OLVERA', 'DWAYNE.OLVERA@sakilacustomer.org', 560, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (555, 1, 'DWIGHT', 'LOMBARDI', 'DWIGHT.LOMBARDI@sakilacustomer.org', 561, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (556, 2, 'ARMANDO', 'GRUBER', 'ARMANDO.GRUBER@sakilacustomer.org', 562, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (557, 1, 'FELIX', 'GAFFNEY', 'FELIX.GAFFNEY@sakilacustomer.org', 563, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (559, 2, 'EVERETT', 'BANDA', 'EVERETT.BANDA@sakilacustomer.org', 565, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (560, 1, 'JORDAN', 'ARCHULETA', 'JORDAN.ARCHULETA@sakilacustomer.org', 566, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (561, 2, 'IAN', 'STILL', 'IAN.STILL@sakilacustomer.org', 567, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (562, 1, 'WALLACE', 'SLONE', 'WALLACE.SLONE@sakilacustomer.org', 568, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (563, 2, 'KEN', 'PREWITT', 'KEN.PREWITT@sakilacustomer.org', 569, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (564, 2, 'BOB', 'PFEIFFER', 'BOB.PFEIFFER@sakilacustomer.org', 570, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (565, 2, 'JAIME', 'NETTLES', 'JAIME.NETTLES@sakilacustomer.org', 571, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (566, 1, 'CASEY', 'MENA', 'CASEY.MENA@sakilacustomer.org', 572, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (567, 2, 'ALFREDO', 'MCADAMS', 'ALFREDO.MCADAMS@sakilacustomer.org', 573, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (568, 2, 'ALBERTO', 'HENNING', 'ALBERTO.HENNING@sakilacustomer.org', 574, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (569, 2, 'DAVE', 'GARDINER', 'DAVE.GARDINER@sakilacustomer.org', 575, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (570, 2, 'IVAN', 'CROMWELL', 'IVAN.CROMWELL@sakilacustomer.org', 576, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (571, 2, 'JOHNNIE', 'CHISHOLM', 'JOHNNIE.CHISHOLM@sakilacustomer.org', 577, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (572, 1, 'SIDNEY', 'BURLESON', 'SIDNEY.BURLESON@sakilacustomer.org', 578, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (573, 1, 'BYRON', 'BOX', 'BYRON.BOX@sakilacustomer.org', 579, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (574, 2, 'JULIAN', 'VEST', 'JULIAN.VEST@sakilacustomer.org', 580, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (575, 2, 'ISAAC', 'OGLESBY', 'ISAAC.OGLESBY@sakilacustomer.org', 581, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (576, 2, 'MORRIS', 'MCCARTER', 'MORRIS.MCCARTER@sakilacustomer.org', 582, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (577, 2, 'CLIFTON', 'MALCOLM', 'CLIFTON.MALCOLM@sakilacustomer.org', 583, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (578, 2, 'WILLARD', 'LUMPKIN', 'WILLARD.LUMPKIN@sakilacustomer.org', 584, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (579, 2, 'DARYL', 'LARUE', 'DARYL.LARUE@sakilacustomer.org', 585, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (580, 1, 'ROSS', 'GREY', 'ROSS.GREY@sakilacustomer.org', 586, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (581, 1, 'VIRGIL', 'WOFFORD', 'VIRGIL.WOFFORD@sakilacustomer.org', 587, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (582, 2, 'ANDY', 'VANHORN', 'ANDY.VANHORN@sakilacustomer.org', 588, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (583, 1, 'MARSHALL', 'THORN', 'MARSHALL.THORN@sakilacustomer.org', 589, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (584, 2, 'SALVADOR', 'TEEL', 'SALVADOR.TEEL@sakilacustomer.org', 590, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (585, 1, 'PERRY', 'SWAFFORD', 'PERRY.SWAFFORD@sakilacustomer.org', 591, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (586, 1, 'KIRK', 'STCLAIR', 'KIRK.STCLAIR@sakilacustomer.org', 592, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (587, 1, 'SERGIO', 'STANFIELD', 'SERGIO.STANFIELD@sakilacustomer.org', 593, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (588, 1, 'MARION', 'OCAMPO', 'MARION.OCAMPO@sakilacustomer.org', 594, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (589, 1, 'TRACY', 'HERRMANN', 'TRACY.HERRMANN@sakilacustomer.org', 595, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (590, 2, 'SETH', 'HANNON', 'SETH.HANNON@sakilacustomer.org', 596, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (591, 1, 'KENT', 'ARSENAULT', 'KENT.ARSENAULT@sakilacustomer.org', 597, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (593, 2, 'RENE', 'MCALISTER', 'RENE.MCALISTER@sakilacustomer.org', 599, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (594, 1, 'EDUARDO', 'HIATT', 'EDUARDO.HIATT@sakilacustomer.org', 600, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (595, 1, 'TERRENCE', 'GUNDERSON', 'TERRENCE.GUNDERSON@sakilacustomer.org', 601, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (596, 1, 'ENRIQUE', 'FORSYTHE', 'ENRIQUE.FORSYTHE@sakilacustomer.org', 602, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (597, 1, 'FREDDIE', 'DUGGAN', 'FREDDIE.DUGGAN@sakilacustomer.org', 603, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (598, 1, 'WADE', 'DELVALLE', 'WADE.DELVALLE@sakilacustomer.org', 604, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (599, 2, 'AUSTIN', 'CINTRON', 'AUSTIN.CINTRON@sakilacustomer.org', 605, 1, datetime.datetime(2006, 2, 14, 22, 4, 37), datetime.datetime(2006, 2, 15, 4, 57, 20))]

# %% [markdown]
# ### VIEW naming convention
# VIEWS are commonly turned into tables at some point.
# Prevents application code updates:
# ```
# SELECT *
# FROM active_customer;
# ```
#
# versus
#
# ```
# SELECT *
# FROM view_active_customer;
# ```

# %% [markdown]
# ### List VIEWS

# %%
# %%sql
# SHOW FULL TABLES
# WHERE Table_type = 'VIEW';
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 1 rows affected.
# [('active_customer', 'VIEW')]

# %% [markdown]
# ### Displaying the VIEW's definition

# %%
# %%sql
# SHOW CREATE VIEW active_customer;
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 1 rows affected.
# [('active_customer', 'CREATE ALGORITHM=UNDEFINED DEFINER=`itaylmub_dba`@`%` SQL SECURITY DEFINER VIEW `active_customer` AS select `customer`.`customer_id` AS `customer_id` ... (199 characters truncated) ... tive` AS `active`,`customer`.`create_date` AS `create_date`,`customer`.`last_update` AS `last_update` from `customer` where (`customer`.`active` = 1)', 'latin1', 'latin1_swedish_ci')]

# %% [markdown]
# ### 2. Data security
# Limiting access to certain columns. Hiding sensitive information.
#
# Only displaying the active customer's first name, last name, and email.
# Obscuring the email to prevent malicious usage to look like this: MA\*\*\*\*\*.org.
# Replacing the active_customer VIEW.

# %%
# %%sql
# CREATE OR REPLACE VIEW active_customer AS
#     SELECT
#         first_name,
#         last_name,
#         CONCAT(
#             SUBSTRING(email,1,2),
#             '*****',
#             SUBSTRING(email,-4)
#     ) AS obscured_email
#     FROM customer
#     WHERE active = 1;
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 0 rows affected.
# []

# %% [markdown]
# Verifying the new VIEW definition.

# %%
# %%sql
# SELECT *
# FROM active_customer;
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 584 rows affected.
# [('MARY', 'SMITH', 'MA*****.org'),
#  ('PATRICIA', 'JOHNSON', 'PA*****.org'),
#  ('LINDA', 'WILLIAMS', 'LI*****.org'),
#  ('BARBARA', 'JONES', 'BA*****.org'),
#  ('ELIZABETH', 'BROWN', 'EL*****.org'),
#  ('JENNIFER', 'DAVIS', 'JE*****.org'),
#  ('MARIA', 'MILLER', 'MA*****.org'),
#  ('SUSAN', 'WILSON', 'SU*****.org'),
#  ('MARGARET', 'MOORE', 'MA*****.org'),
#  ('DOROTHY', 'TAYLOR', 'DO*****.org'),
#  ('LISA', 'ANDERSON', 'LI*****.org'),
#  ('NANCY', 'THOMAS', 'NA*****.org'),
#  ('KAREN', 'JACKSON', 'KA*****.org'),
#  ('BETTY', 'WHITE', 'BE*****.org'),
#  ('HELEN', 'HARRIS', 'HE*****.org'),
#  ('DONNA', 'THOMPSON', 'DO*****.org'),
#  ('CAROL', 'GARCIA', 'CA*****.org'),
#  ('RUTH', 'MARTINEZ', 'RU*****.org'),
#  ('SHARON', 'ROBINSON', 'SH*****.org'),
#  ('MICHELLE', 'CLARK', 'MI*****.org'),
#  ('LAURA', 'RODRIGUEZ', 'LA*****.org'),
#  ('SARAH', 'LEWIS', 'SA*****.org'),
#  ('KIMBERLY', 'LEE', 'KI*****.org'),
#  ('DEBORAH', 'WALKER', 'DE*****.org'),
#  ('JESSICA', 'HALL', 'JE*****.org'),
#  ('SHIRLEY', 'ALLEN', 'SH*****.org'),
#  ('CYNTHIA', 'YOUNG', 'CY*****.org'),
#  ('ANGELA', 'HERNANDEZ', 'AN*****.org'),
#  ('MELISSA', 'KING', 'ME*****.org'),
#  ('BRENDA', 'WRIGHT', 'BR*****.org'),
#  ('AMY', 'LOPEZ', 'AM*****.org'),
#  ('ANNA', 'HILL', 'AN*****.org'),
#  ('REBECCA', 'SCOTT', 'RE*****.org'),
#  ('VIRGINIA', 'GREEN', 'VI*****.org'),
#  ('KATHLEEN', 'ADAMS', 'KA*****.org'),
#  ('PAMELA', 'BAKER', 'PA*****.org'),
#  ('MARTHA', 'GONZALEZ', 'MA*****.org'),
#  ('DEBRA', 'NELSON', 'DE*****.org'),
#  ('AMANDA', 'CARTER', 'AM*****.org'),
#  ('STEPHANIE', 'MITCHELL', 'ST*****.org'),
#  ('CAROLYN', 'PEREZ', 'CA*****.org'),
#  ('CHRISTINE', 'ROBERTS', 'CH*****.org'),
#  ('MARIE', 'TURNER', 'MA*****.org'),
#  ('JANET', 'PHILLIPS', 'JA*****.org'),
#  ('CATHERINE', 'CAMPBELL', 'CA*****.org'),
#  ('FRANCES', 'PARKER', 'FR*****.org'),
#  ('ANN', 'EVANS', 'AN*****.org'),
#  ('JOYCE', 'EDWARDS', 'JO*****.org'),
#  ('DIANE', 'COLLINS', 'DI*****.org'),
#  ('ALICE', 'STEWART', 'AL*****.org'),
#  ('JULIE', 'SANCHEZ', 'JU*****.org'),
#  ('HEATHER', 'MORRIS', 'HE*****.org'),
#  ('TERESA', 'ROGERS', 'TE*****.org'),
#  ('DORIS', 'REED', 'DO*****.org'),
#  ('GLORIA', 'COOK', 'GL*****.org'),
#  ('EVELYN', 'MORGAN', 'EV*****.org'),
#  ('JEAN', 'BELL', 'JE*****.org'),
#  ('CHERYL', 'MURPHY', 'CH*****.org'),
#  ('MILDRED', 'BAILEY', 'MI*****.org'),
#  ('KATHERINE', 'RIVERA', 'KA*****.org'),
#  ('JOAN', 'COOPER', 'JO*****.org'),
#  ('ASHLEY', 'RICHARDSON', 'AS*****.org'),
#  ('ROSE', 'HOWARD', 'RO*****.org'),
#  ('JANICE', 'WARD', 'JA*****.org'),
#  ('KELLY', 'TORRES', 'KE*****.org'),
#  ('NICOLE', 'PETERSON', 'NI*****.org'),
#  ('JUDY', 'GRAY', 'JU*****.org'),
#  ('CHRISTINA', 'RAMIREZ', 'CH*****.org'),
#  ('KATHY', 'JAMES', 'KA*****.org'),
#  ('THERESA', 'WATSON', 'TH*****.org'),
#  ('BEVERLY', 'BROOKS', 'BE*****.org'),
#  ('DENISE', 'KELLY', 'DE*****.org'),
#  ('TAMMY', 'SANDERS', 'TA*****.org'),
#  ('IRENE', 'PRICE', 'IR*****.org'),
#  ('JANE', 'BENNETT', 'JA*****.org'),
#  ('LORI', 'WOOD', 'LO*****.org'),
#  ('RACHEL', 'BARNES', 'RA*****.org'),
#  ('MARILYN', 'ROSS', 'MA*****.org'),
#  ('ANDREA', 'HENDERSON', 'AN*****.org'),
#  ('KATHRYN', 'COLEMAN', 'KA*****.org'),
#  ('LOUISE', 'JENKINS', 'LO*****.org'),
#  ('SARA', 'PERRY', 'SA*****.org'),
#  ('ANNE', 'POWELL', 'AN*****.org'),
#  ('JACQUELINE', 'LONG', 'JA*****.org'),
#  ('WANDA', 'PATTERSON', 'WA*****.org'),
#  ('BONNIE', 'HUGHES', 'BO*****.org'),
#  ('JULIA', 'FLORES', 'JU*****.org'),
#  ('RUBY', 'WASHINGTON', 'RU*****.org'),
#  ('LOIS', 'BUTLER', 'LO*****.org'),
#  ('TINA', 'SIMMONS', 'TI*****.org'),
#  ('PHYLLIS', 'FOSTER', 'PH*****.org'),
#  ('NORMA', 'GONZALES', 'NO*****.org'),
#  ('PAULA', 'BRYANT', 'PA*****.org'),
#  ('DIANA', 'ALEXANDER', 'DI*****.org'),
#  ('ANNIE', 'RUSSELL', 'AN*****.org'),
#  ('LILLIAN', 'GRIFFIN', 'LI*****.org'),
#  ('EMILY', 'DIAZ', 'EM*****.org'),
#  ('ROBIN', 'HAYES', 'RO*****.org'),
#  ('PEGGY', 'MYERS', 'PE*****.org'),
#  ('CRYSTAL', 'FORD', 'CR*****.org'),
#  ('GLADYS', 'HAMILTON', 'GL*****.org'),
#  ('RITA', 'GRAHAM', 'RI*****.org'),
#  ('DAWN', 'SULLIVAN', 'DA*****.org'),
#  ('CONNIE', 'WALLACE', 'CO*****.org'),
#  ('FLORENCE', 'WOODS', 'FL*****.org'),
#  ('TRACY', 'COLE', 'TR*****.org'),
#  ('EDNA', 'WEST', 'ED*****.org'),
#  ('TIFFANY', 'JORDAN', 'TI*****.org'),
#  ('CARMEN', 'OWENS', 'CA*****.org'),
#  ('ROSA', 'REYNOLDS', 'RO*****.org'),
#  ('CINDY', 'FISHER', 'CI*****.org'),
#  ('GRACE', 'ELLIS', 'GR*****.org'),
#  ('WENDY', 'HARRISON', 'WE*****.org'),
#  ('VICTORIA', 'GIBSON', 'VI*****.org'),
#  ('EDITH', 'MCDONALD', 'ED*****.org'),
#  ('KIM', 'CRUZ', 'KI*****.org'),
#  ('SHERRY', 'MARSHALL', 'SH*****.org'),
#  ('SYLVIA', 'ORTIZ', 'SY*****.org'),
#  ('JOSEPHINE', 'GOMEZ', 'JO*****.org'),
#  ('THELMA', 'MURRAY', 'TH*****.org'),
#  ('SHANNON', 'FREEMAN', 'SH*****.org'),
#  ('ETHEL', 'WEBB', 'ET*****.org'),
#  ('ELLEN', 'SIMPSON', 'EL*****.org'),
#  ('ELAINE', 'STEVENS', 'EL*****.org'),
#  ('MARJORIE', 'TUCKER', 'MA*****.org'),
#  ('CARRIE', 'PORTER', 'CA*****.org'),
#  ('CHARLOTTE', 'HUNTER', 'CH*****.org'),
#  ('MONICA', 'HICKS', 'MO*****.org'),
#  ('ESTHER', 'CRAWFORD', 'ES*****.org'),
#  ('PAULINE', 'HENRY', 'PA*****.org'),
#  ('EMMA', 'BOYD', 'EM*****.org'),
#  ('JUANITA', 'MASON', 'JU*****.org'),
#  ('ANITA', 'MORALES', 'AN*****.org'),
#  ('RHONDA', 'KENNEDY', 'RH*****.org'),
#  ('HAZEL', 'WARREN', 'HA*****.org'),
#  ('AMBER', 'DIXON', 'AM*****.org'),
#  ('EVA', 'RAMOS', 'EV*****.org'),
#  ('DEBBIE', 'REYES', 'DE*****.org'),
#  ('APRIL', 'BURNS', 'AP*****.org'),
#  ('LESLIE', 'GORDON', 'LE*****.org'),
#  ('CLARA', 'SHAW', 'CL*****.org'),
#  ('LUCILLE', 'HOLMES', 'LU*****.org'),
#  ('JAMIE', 'RICE', 'JA*****.org'),
#  ('JOANNE', 'ROBERTSON', 'JO*****.org'),
#  ('ELEANOR', 'HUNT', 'EL*****.org'),
#  ('VALERIE', 'BLACK', 'VA*****.org'),
#  ('DANIELLE', 'DANIELS', 'DA*****.org'),
#  ('MEGAN', 'PALMER', 'ME*****.org'),
#  ('ALICIA', 'MILLS', 'AL*****.org'),
#  ('SUZANNE', 'NICHOLS', 'SU*****.org'),
#  ('MICHELE', 'GRANT', 'MI*****.org'),
#  ('GAIL', 'KNIGHT', 'GA*****.org'),
#  ('BERTHA', 'FERGUSON', 'BE*****.org'),
#  ('DARLENE', 'ROSE', 'DA*****.org'),
#  ('VERONICA', 'STONE', 'VE*****.org'),
#  ('JILL', 'HAWKINS', 'JI*****.org'),
#  ('ERIN', 'DUNN', 'ER*****.org'),
#  ('GERALDINE', 'PERKINS', 'GE*****.org'),
#  ('LAUREN', 'HUDSON', 'LA*****.org'),
#  ('CATHY', 'SPENCER', 'CA*****.org'),
#  ('JOANN', 'GARDNER', 'JO*****.org'),
#  ('LORRAINE', 'STEPHENS', 'LO*****.org'),
#  ('LYNN', 'PAYNE', 'LY*****.org'),
#  ('SALLY', 'PIERCE', 'SA*****.org'),
#  ('REGINA', 'BERRY', 'RE*****.org'),
#  ('BEATRICE', 'ARNOLD', 'BE*****.org'),
#  ('DOLORES', 'WAGNER', 'DO*****.org'),
#  ('BERNICE', 'WILLIS', 'BE*****.org'),
#  ('AUDREY', 'RAY', 'AU*****.org'),
#  ('YVONNE', 'WATKINS', 'YV*****.org'),
#  ('ANNETTE', 'OLSON', 'AN*****.org'),
#  ('JUNE', 'CARROLL', 'JU*****.org'),
#  ('SAMANTHA', 'DUNCAN', 'SA*****.org'),
#  ('MARION', 'SNYDER', 'MA*****.org'),
#  ('DANA', 'HART', 'DA*****.org'),
#  ('STACY', 'CUNNINGHAM', 'ST*****.org'),
#  ('ANA', 'BRADLEY', 'AN*****.org'),
#  ('RENEE', 'LANE', 'RE*****.org'),
#  ('IDA', 'ANDREWS', 'ID*****.org'),
#  ('VIVIAN', 'RUIZ', 'VI*****.org'),
#  ('ROBERTA', 'HARPER', 'RO*****.org'),
#  ('HOLLY', 'FOX', 'HO*****.org'),
#  ('BRITTANY', 'RILEY', 'BR*****.org'),
#  ('MELANIE', 'ARMSTRONG', 'ME*****.org'),
#  ('LORETTA', 'CARPENTER', 'LO*****.org'),
#  ('YOLANDA', 'WEAVER', 'YO*****.org'),
#  ('JEANETTE', 'GREENE', 'JE*****.org'),
#  ('LAURIE', 'LAWRENCE', 'LA*****.org'),
#  ('KATIE', 'ELLIOTT', 'KA*****.org'),
#  ('KRISTEN', 'CHAVEZ', 'KR*****.org'),
#  ('VANESSA', 'SIMS', 'VA*****.org'),
#  ('ALMA', 'AUSTIN', 'AL*****.org'),
#  ('SUE', 'PETERS', 'SU*****.org'),
#  ('ELSIE', 'KELLEY', 'EL*****.org'),
#  ('BETH', 'FRANKLIN', 'BE*****.org'),
#  ('JEANNE', 'LAWSON', 'JE*****.org'),
#  ('VICKI', 'FIELDS', 'VI*****.org'),
#  ('CARLA', 'GUTIERREZ', 'CA*****.org'),
#  ('TARA', 'RYAN', 'TA*****.org'),
#  ('ROSEMARY', 'SCHMIDT', 'RO*****.org'),
#  ('EILEEN', 'CARR', 'EI*****.org'),
#  ('TERRI', 'VASQUEZ', 'TE*****.org'),
#  ('GERTRUDE', 'CASTILLO', 'GE*****.org'),
#  ('LUCY', 'WHEELER', 'LU*****.org'),
#  ('TONYA', 'CHAPMAN', 'TO*****.org'),
#  ('ELLA', 'OLIVER', 'EL*****.org'),
#  ('STACEY', 'MONTGOMERY', 'ST*****.org'),
#  ('WILMA', 'RICHARDS', 'WI*****.org'),
#  ('GINA', 'WILLIAMSON', 'GI*****.org'),
#  ('KRISTIN', 'JOHNSTON', 'KR*****.org'),
#  ('JESSIE', 'BANKS', 'JE*****.org'),
#  ('NATALIE', 'MEYER', 'NA*****.org'),
#  ('AGNES', 'BISHOP', 'AG*****.org'),
#  ('VERA', 'MCCOY', 'VE*****.org'),
#  ('WILLIE', 'HOWELL', 'WI*****.org'),
#  ('CHARLENE', 'ALVAREZ', 'CH*****.org'),
#  ('BESSIE', 'MORRISON', 'BE*****.org'),
#  ('DELORES', 'HANSEN', 'DE*****.org'),
#  ('MELINDA', 'FERNANDEZ', 'ME*****.org'),
#  ('PEARL', 'GARZA', 'PE*****.org'),
#  ('ARLENE', 'HARVEY', 'AR*****.org'),
#  ('MAUREEN', 'LITTLE', 'MA*****.org'),
#  ('COLLEEN', 'BURTON', 'CO*****.org'),
#  ('ALLISON', 'STANLEY', 'AL*****.org'),
#  ('TAMARA', 'NGUYEN', 'TA*****.org'),
#  ('JOY', 'GEORGE', 'JO*****.org'),
#  ('GEORGIA', 'JACOBS', 'GE*****.org'),
#  ('CONSTANCE', 'REID', 'CO*****.org'),
#  ('LILLIE', 'KIM', 'LI*****.org'),
#  ('CLAUDIA', 'FULLER', 'CL*****.org'),
#  ('JACKIE', 'LYNCH', 'JA*****.org'),
#  ('MARCIA', 'DEAN', 'MA*****.org'),
#  ('TANYA', 'GILBERT', 'TA*****.org'),
#  ('NELLIE', 'GARRETT', 'NE*****.org'),
#  ('MINNIE', 'ROMERO', 'MI*****.org'),
#  ('MARLENE', 'WELCH', 'MA*****.org'),
#  ('GLENDA', 'FRAZIER', 'GL*****.org'),
#  ('LYDIA', 'BURKE', 'LY*****.org'),
#  ('VIOLA', 'HANSON', 'VI*****.org'),
#  ('COURTNEY', 'DAY', 'CO*****.org'),
#  ('MARIAN', 'MENDOZA', 'MA*****.org'),
#  ('STELLA', 'MORENO', 'ST*****.org'),
#  ('CAROLINE', 'BOWMAN', 'CA*****.org'),
#  ('DORA', 'MEDINA', 'DO*****.org'),
#  ('JO', 'FOWLER', 'JO*****.org'),
#  ('VICKIE', 'BREWER', 'VI*****.org'),
#  ('MATTIE', 'HOFFMAN', 'MA*****.org'),
#  ('TERRY', 'CARLSON', 'TE*****.org'),
#  ('MAXINE', 'SILVA', 'MA*****.org'),
#  ('IRMA', 'PEARSON', 'IR*****.org'),
#  ('MABEL', 'HOLLAND', 'MA*****.org'),
#  ('MARSHA', 'DOUGLAS', 'MA*****.org'),
#  ('MYRTLE', 'FLEMING', 'MY*****.org'),
#  ('LENA', 'JENSEN', 'LE*****.org'),
#  ('CHRISTY', 'VARGAS', 'CH*****.org'),
#  ('DEANNA', 'BYRD', 'DE*****.org'),
#  ('PATSY', 'DAVIDSON', 'PA*****.org'),
#  ('HILDA', 'HOPKINS', 'HI*****.org'),
#  ('GWENDOLYN', 'MAY', 'GW*****.org'),
#  ('JENNIE', 'TERRY', 'JE*****.org'),
#  ('NORA', 'HERRERA', 'NO*****.org'),
#  ('MARGIE', 'WADE', 'MA*****.org'),
#  ('NINA', 'SOTO', 'NI*****.org'),
#  ('CASSANDRA', 'WALTERS', 'CA*****.org'),
#  ('LEAH', 'CURTIS', 'LE*****.org'),
#  ('KAY', 'CALDWELL', 'KA*****.org'),
#  ('PRISCILLA', 'LOWE', 'PR*****.org'),
#  ('NAOMI', 'JENNINGS', 'NA*****.org'),
#  ('CAROLE', 'BARNETT', 'CA*****.org'),
#  ('BRANDY', 'GRAVES', 'BR*****.org'),
#  ('OLGA', 'JIMENEZ', 'OL*****.org'),
#  ('BILLIE', 'HORTON', 'BI*****.org'),
#  ('DIANNE', 'SHELTON', 'DI*****.org'),
#  ('TRACEY', 'BARRETT', 'TR*****.org'),
#  ('LEONA', 'OBRIEN', 'LE*****.org'),
#  ('JENNY', 'CASTRO', 'JE*****.org'),
#  ('FELICIA', 'SUTTON', 'FE*****.org'),
#  ('SONIA', 'GREGORY', 'SO*****.org'),
#  ('MIRIAM', 'MCKINNEY', 'MI*****.org'),
#  ('VELMA', 'LUCAS', 'VE*****.org'),
#  ('BECKY', 'MILES', 'BE*****.org'),
#  ('BOBBIE', 'CRAIG', 'BO*****.org'),
#  ('VIOLET', 'RODRIQUEZ', 'VI*****.org'),
#  ('KRISTINA', 'CHAMBERS', 'KR*****.org'),
#  ('TONI', 'HOLT', 'TO*****.org'),
#  ('MISTY', 'LAMBERT', 'MI*****.org'),
#  ('MAE', 'FLETCHER', 'MA*****.org'),
#  ('SHELLY', 'WATTS', 'SH*****.org'),
#  ('DAISY', 'BATES', 'DA*****.org'),
#  ('RAMONA', 'HALE', 'RA*****.org'),
#  ('SHERRI', 'RHODES', 'SH*****.org'),
#  ('ERIKA', 'PENA', 'ER*****.org'),
#  ('JAMES', 'GANNON', 'JA*****.org'),
#  ('JOHN', 'FARNSWORTH', 'JO*****.org'),
#  ('ROBERT', 'BAUGHMAN', 'RO*****.org'),
#  ('MICHAEL', 'SILVERMAN', 'MI*****.org'),
#  ('WILLIAM', 'SATTERFIELD', 'WI*****.org'),
#  ('DAVID', 'ROYAL', 'DA*****.org'),
#  ('RICHARD', 'MCCRARY', 'RI*****.org'),
#  ('CHARLES', 'KOWALSKI', 'CH*****.org'),
#  ('JOSEPH', 'JOY', 'JO*****.org'),
#  ('THOMAS', 'GRIGSBY', 'TH*****.org'),
#  ('CHRISTOPHER', 'GRECO', 'CH*****.org'),
#  ('DANIEL', 'CABRAL', 'DA*****.org'),
#  ('PAUL', 'TROUT', 'PA*****.org'),
#  ('MARK', 'RINEHART', 'MA*****.org'),
#  ('DONALD', 'MAHON', 'DO*****.org'),
#  ('GEORGE', 'LINTON', 'GE*****.org'),
#  ('STEVEN', 'CURLEY', 'ST*****.org'),
#  ('EDWARD', 'BAUGH', 'ED*****.org'),
#  ('BRIAN', 'WYMAN', 'BR*****.org'),
#  ('RONALD', 'WEINER', 'RO*****.org'),
#  ('ANTHONY', 'SCHWAB', 'AN*****.org'),
#  ('KEVIN', 'SCHULER', 'KE*****.org'),
#  ('JASON', 'MORRISSEY', 'JA*****.org'),
#  ('MATTHEW', 'MAHAN', 'MA*****.org'),
#  ('GARY', 'COY', 'GA*****.org'),
#  ('TIMOTHY', 'BUNN', 'TI*****.org'),
#  ('JOSE', 'ANDREW', 'JO*****.org'),
#  ('LARRY', 'THRASHER', 'LA*****.org'),
#  ('JEFFREY', 'SPEAR', 'JE*****.org'),
#  ('FRANK', 'WAGGONER', 'FR*****.org'),
#  ('SCOTT', 'SHELLEY', 'SC*****.org'),
#  ('ERIC', 'ROBERT', 'ER*****.org'),
#  ('STEPHEN', 'QUALLS', 'ST*****.org'),
#  ('ANDREW', 'PURDY', 'AN*****.org'),
#  ('RAYMOND', 'MCWHORTER', 'RA*****.org'),
#  ('GREGORY', 'MAULDIN', 'GR*****.org'),
#  ('JOSHUA', 'MARK', 'JO*****.org'),
#  ('JERRY', 'JORDON', 'JE*****.org'),
#  ('DENNIS', 'GILMAN', 'DE*****.org'),
#  ('WALTER', 'PERRYMAN', 'WA*****.org'),
#  ('PATRICK', 'NEWSOM', 'PA*****.org'),
#  ('PETER', 'MENARD', 'PE*****.org'),
#  ('HAROLD', 'MARTINO', 'HA*****.org'),
#  ('DOUGLAS', 'GRAF', 'DO*****.org'),
#  ('HENRY', 'BILLINGSLEY', 'HE*****.org'),
#  ('CARL', 'ARTIS', 'CA*****.org'),
#  ('ARTHUR', 'SIMPKINS', 'AR*****.org'),
#  ('RYAN', 'SALISBURY', 'RY*****.org'),
#  ('ROGER', 'QUINTANILLA', 'RO*****.org'),
#  ('JOE', 'GILLILAND', 'JO*****.org'),
#  ('JUAN', 'FRALEY', 'JU*****.org'),
#  ('JACK', 'FOUST', 'JA*****.org'),
#  ('ALBERT', 'CROUSE', 'AL*****.org'),
#  ('JONATHAN', 'SCARBOROUGH', 'JO*****.org'),
#  ('JUSTIN', 'NGO', 'JU*****.org'),
#  ('TERRY', 'GRISSOM', 'TE*****.org'),
#  ('GERALD', 'FULTZ', 'GE*****.org'),
#  ('KEITH', 'RICO', 'KE*****.org'),
#  ('SAMUEL', 'MARLOW', 'SA*****.org'),
#  ('WILLIE', 'MARKHAM', 'WI*****.org'),
#  ('RALPH', 'MADRIGAL', 'RA*****.org'),
#  ('LAWRENCE', 'LAWTON', 'LA*****.org'),
#  ('NICHOLAS', 'BARFIELD', 'NI*****.org'),
#  ('ROY', 'WHITING', 'RO*****.org'),
#  ('BENJAMIN', 'VARNEY', 'BE*****.org'),
#  ('BRUCE', 'SCHWARZ', 'BR*****.org'),
#  ('BRANDON', 'HUEY', 'BR*****.org'),
#  ('ADAM', 'GOOCH', 'AD*****.org'),
#  ('FRED', 'WHEAT', 'FR*****.org'),
#  ('WAYNE', 'TRUONG', 'WA*****.org'),
#  ('BILLY', 'POULIN', 'BI*****.org'),
#  ('STEVE', 'MACKENZIE', 'ST*****.org'),
#  ('LOUIS', 'LEONE', 'LO*****.org'),
#  ('JEREMY', 'HURTADO', 'JE*****.org'),
#  ('AARON', 'SELBY', 'AA*****.org'),
#  ('RANDY', 'GAITHER', 'RA*****.org'),
#  ('HOWARD', 'FORTNER', 'HO*****.org'),
#  ('EUGENE', 'CULPEPPER', 'EU*****.org'),
#  ('CARLOS', 'COUGHLIN', 'CA*****.org'),
#  ('RUSSELL', 'BRINSON', 'RU*****.org'),
#  ('BOBBY', 'BOUDREAU', 'BO*****.org'),
#  ('VICTOR', 'BARKLEY', 'VI*****.org'),
#  ('MARTIN', 'BALES', 'MA*****.org'),
#  ('ERNEST', 'STEPP', 'ER*****.org'),
#  ('PHILLIP', 'HOLM', 'PH*****.org'),
#  ('TODD', 'TAN', 'TO*****.org'),
#  ('JESSE', 'SCHILLING', 'JE*****.org'),
#  ('CRAIG', 'MORRELL', 'CR*****.org'),
#  ('ALAN', 'KAHN', 'AL*****.org'),
#  ('SHAWN', 'HEATON', 'SH*****.org'),
#  ('CLARENCE', 'GAMEZ', 'CL*****.org'),
#  ('SEAN', 'DOUGLASS', 'SE*****.org'),
#  ('PHILIP', 'CAUSEY', 'PH*****.org'),
#  ('CHRIS', 'BROTHERS', 'CH*****.org'),
#  ('JOHNNY', 'TURPIN', 'JO*****.org'),
#  ('EARL', 'SHANKS', 'EA*****.org'),
#  ('JIMMY', 'SCHRADER', 'JI*****.org'),
#  ('ANTONIO', 'MEEK', 'AN*****.org'),
#  ('DANNY', 'ISOM', 'DA*****.org'),
#  ('BRYAN', 'HARDISON', 'BR*****.org'),
#  ('TONY', 'CARRANZA', 'TO*****.org'),
#  ('LUIS', 'YANEZ', 'LU*****.org'),
#  ('MIKE', 'WAY', 'MI*****.org'),
#  ('STANLEY', 'SCROGGINS', 'ST*****.org'),
#  ('LEONARD', 'SCHOFIELD', 'LE*****.org'),
#  ('DALE', 'RATCLIFF', 'DA*****.org'),
#  ('MANUEL', 'MURRELL', 'MA*****.org'),
#  ('RODNEY', 'MOELLER', 'RO*****.org'),
#  ('CURTIS', 'IRBY', 'CU*****.org'),
#  ('NORMAN', 'CURRIER', 'NO*****.org'),
#  ('ALLEN', 'BUTTERFIELD', 'AL*****.org'),
#  ('MARVIN', 'YEE', 'MA*****.org'),
#  ('VINCENT', 'RALSTON', 'VI*****.org'),
#  ('GLENN', 'PULLEN', 'GL*****.org'),
#  ('JEFFERY', 'PINSON', 'JE*****.org'),
#  ('TRAVIS', 'ESTEP', 'TR*****.org'),
#  ('JEFF', 'EAST', 'JE*****.org'),
#  ('CHAD', 'CARBONE', 'CH*****.org'),
#  ('JACOB', 'LANCE', 'JA*****.org'),
#  ('LEE', 'HAWKS', 'LE*****.org'),
#  ('MELVIN', 'ELLINGTON', 'ME*****.org'),
#  ('ALFRED', 'CASILLAS', 'AL*****.org'),
#  ('KYLE', 'SPURLOCK', 'KY*****.org'),
#  ('FRANCIS', 'SIKES', 'FR*****.org'),
#  ('BRADLEY', 'MOTLEY', 'BR*****.org'),
#  ('JESUS', 'MCCARTNEY', 'JE*****.org'),
#  ('HERBERT', 'KRUGER', 'HE*****.org'),
#  ('FREDERICK', 'ISBELL', 'FR*****.org'),
#  ('RAY', 'HOULE', 'RA*****.org'),
#  ('JOEL', 'FRANCISCO', 'JO*****.org'),
#  ('EDWIN', 'BURK', 'ED*****.org'),
#  ('DON', 'BONE', 'DO*****.org'),
#  ('EDDIE', 'TOMLIN', 'ED*****.org'),
#  ('RICKY', 'SHELBY', 'RI*****.org'),
#  ('TROY', 'QUIGLEY', 'TR*****.org'),
#  ('RANDALL', 'NEUMANN', 'RA*****.org'),
#  ('BARRY', 'LOVELACE', 'BA*****.org'),
#  ('ALEXANDER', 'FENNELL', 'AL*****.org'),
#  ('BERNARD', 'COLBY', 'BE*****.org'),
#  ('MARIO', 'CHEATHAM', 'MA*****.org'),
#  ('LEROY', 'BUSTAMANTE', 'LE*****.org'),
#  ('FRANCISCO', 'SKIDMORE', 'FR*****.org'),
#  ('MARCUS', 'HIDALGO', 'MA*****.org'),
#  ('MICHEAL', 'FORMAN', 'MI*****.org'),
#  ('CLIFFORD', 'BOWENS', 'CL*****.org'),
#  ('MIGUEL', 'BETANCOURT', 'MI*****.org'),
#  ('OSCAR', 'AQUINO', 'OS*****.org'),
#  ('JAY', 'ROBB', 'JA*****.org'),
#  ('JIM', 'REA', 'JI*****.org'),
#  ('TOM', 'MILNER', 'TO*****.org'),
#  ('CALVIN', 'MARTEL', 'CA*****.org'),
#  ('ALEX', 'GRESHAM', 'AL*****.org'),
#  ('JON', 'WILES', 'JO*****.org'),
#  ('RONNIE', 'RICKETTS', 'RO*****.org'),
#  ('BILL', 'GAVIN', 'BI*****.org'),
#  ('LLOYD', 'DOWD', 'LL*****.org'),
#  ('TOMMY', 'COLLAZO', 'TO*****.org'),
#  ('LEON', 'BOSTIC', 'LE*****.org'),
#  ('DEREK', 'BLAKELY', 'DE*****.org'),
#  ('WARREN', 'SHERROD', 'WA*****.org'),
#  ('DARRELL', 'POWER', 'DA*****.org'),
#  ('JEROME', 'KENYON', 'JE*****.org'),
#  ('FLOYD', 'GANDY', 'FL*****.org'),
#  ('LEO', 'EBERT', 'LE*****.org'),
#  ('ALVIN', 'DELOACH', 'AL*****.org'),
#  ('TIM', 'CARY', 'TI*****.org'),
#  ('WESLEY', 'BULL', 'WE*****.org'),
#  ('GORDON', 'ALLARD', 'GO*****.org'),
#  ('DEAN', 'SAUER', 'DE*****.org'),
#  ('GREG', 'ROBINS', 'GR*****.org'),
#  ('JORGE', 'OLIVARES', 'JO*****.org'),
#  ('DUSTIN', 'GILLETTE', 'DU*****.org'),
#  ('PEDRO', 'CHESTNUT', 'PE*****.org'),
#  ('DERRICK', 'BOURQUE', 'DE*****.org'),
#  ('DAN', 'PAINE', 'DA*****.org'),
#  ('LEWIS', 'LYMAN', 'LE*****.org'),
#  ('ZACHARY', 'HITE', 'ZA*****.org'),
#  ('COREY', 'HAUSER', 'CO*****.org'),
#  ('HERMAN', 'DEVORE', 'HE*****.org'),
#  ('VERNON', 'CHAPA', 'VE*****.org'),
#  ('ROBERTO', 'VU', 'RO*****.org'),
#  ('CLYDE', 'TOBIAS', 'CL*****.org'),
#  ('GLEN', 'TALBERT', 'GL*****.org'),
#  ('HECTOR', 'POINDEXTER', 'HE*****.org'),
#  ('SHANE', 'MILLARD', 'SH*****.org'),
#  ('RICARDO', 'MEADOR', 'RI*****.org'),
#  ('SAM', 'MCDUFFIE', 'SA*****.org'),
#  ('RICK', 'MATTOX', 'RI*****.org'),
#  ('LESTER', 'KRAUS', 'LE*****.org'),
#  ('BRENT', 'HARKINS', 'BR*****.org'),
#  ('RAMON', 'CHOATE', 'RA*****.org'),
#  ('CHARLIE', 'BESS', 'CH*****.org'),
#  ('TYLER', 'WREN', 'TY*****.org'),
#  ('GILBERT', 'SLEDGE', 'GI*****.org'),
#  ('GENE', 'SANBORN', 'GE*****.org'),
#  ('MARC', 'OUTLAW', 'MA*****.org'),
#  ('REGINALD', 'KINDER', 'RE*****.org'),
#  ('RUBEN', 'GEARY', 'RU*****.org'),
#  ('BRETT', 'CORNWELL', 'BR*****.org'),
#  ('ANGEL', 'BARCLAY', 'AN*****.org'),
#  ('NATHANIEL', 'ADAM', 'NA*****.org'),
#  ('RAFAEL', 'ABNEY', 'RA*****.org'),
#  ('LESLIE', 'SEWARD', 'LE*****.org'),
#  ('EDGAR', 'RHOADS', 'ED*****.org'),
#  ('MILTON', 'HOWLAND', 'MI*****.org'),
#  ('RAUL', 'FORTIER', 'RA*****.org'),
#  ('CHESTER', 'BENNER', 'CH*****.org'),
#  ('CECIL', 'VINES', 'CE*****.org'),
#  ('DUANE', 'TUBBS', 'DU*****.org'),
#  ('FRANKLIN', 'TROUTMAN', 'FR*****.org'),
#  ('ANDRE', 'RAPP', 'AN*****.org'),
#  ('ELMER', 'NOE', 'EL*****.org'),
#  ('BRAD', 'MCCURDY', 'BR*****.org'),
#  ('GABRIEL', 'HARDER', 'GA*****.org'),
#  ('RON', 'DELUCA', 'RO*****.org'),
#  ('MITCHELL', 'WESTMORELAND', 'MI*****.org'),
#  ('ROLAND', 'SOUTH', 'RO*****.org'),
#  ('ARNOLD', 'HAVENS', 'AR*****.org'),
#  ('HARVEY', 'GUAJARDO', 'HA*****.org'),
#  ('JARED', 'ELY', 'JA*****.org'),
#  ('ADRIAN', 'CLARY', 'AD*****.org'),
#  ('KARL', 'SEAL', 'KA*****.org'),
#  ('CORY', 'MEEHAN', 'CO*****.org'),
#  ('CLAUDE', 'HERZOG', 'CL*****.org'),
#  ('ERIK', 'GUILLEN', 'ER*****.org'),
#  ('DARRYL', 'ASHCRAFT', 'DA*****.org'),
#  ('JAMIE', 'WAUGH', 'JA*****.org'),
#  ('NEIL', 'RENNER', 'NE*****.org'),
#  ('JESSIE', 'MILAM', 'JE*****.org'),
#  ('JAVIER', 'ELROD', 'JA*****.org'),
#  ('FERNANDO', 'CHURCHILL', 'FE*****.org'),
#  ('CLINTON', 'BUFORD', 'CL*****.org'),
#  ('TED', 'BREAUX', 'TE*****.org'),
#  ('MATHEW', 'BOLIN', 'MA*****.org'),
#  ('TYRONE', 'ASHER', 'TY*****.org'),
#  ('DARREN', 'WINDHAM', 'DA*****.org'),
#  ('LONNIE', 'TIRADO', 'LO*****.org'),
#  ('LANCE', 'PEMBERTON', 'LA*****.org'),
#  ('CODY', 'NOLEN', 'CO*****.org'),
#  ('JULIO', 'NOLAND', 'JU*****.org'),
#  ('KELLY', 'KNOTT', 'KE*****.org'),
#  ('KURT', 'EMMONS', 'KU*****.org'),
#  ('ALLAN', 'CORNISH', 'AL*****.org'),
#  ('NELSON', 'CHRISTENSON', 'NE*****.org'),
#  ('GUY', 'BROWNLEE', 'GU*****.org'),
#  ('CLAYTON', 'BARBEE', 'CL*****.org'),
#  ('HUGH', 'WALDROP', 'HU*****.org'),
#  ('MAX', 'PITT', 'MA*****.org'),
#  ('DWAYNE', 'OLVERA', 'DW*****.org'),
#  ('DWIGHT', 'LOMBARDI', 'DW*****.org'),
#  ('ARMANDO', 'GRUBER', 'AR*****.org'),
#  ('FELIX', 'GAFFNEY', 'FE*****.org'),
#  ('EVERETT', 'BANDA', 'EV*****.org'),
#  ('JORDAN', 'ARCHULETA', 'JO*****.org'),
#  ('IAN', 'STILL', 'IA*****.org'),
#  ('WALLACE', 'SLONE', 'WA*****.org'),
#  ('KEN', 'PREWITT', 'KE*****.org'),
#  ('BOB', 'PFEIFFER', 'BO*****.org'),
#  ('JAIME', 'NETTLES', 'JA*****.org'),
#  ('CASEY', 'MENA', 'CA*****.org'),
#  ('ALFREDO', 'MCADAMS', 'AL*****.org'),
#  ('ALBERTO', 'HENNING', 'AL*****.org'),
#  ('DAVE', 'GARDINER', 'DA*****.org'),
#  ('IVAN', 'CROMWELL', 'IV*****.org'),
#  ('JOHNNIE', 'CHISHOLM', 'JO*****.org'),
#  ('SIDNEY', 'BURLESON', 'SI*****.org'),
#  ('BYRON', 'BOX', 'BY*****.org'),
#  ('JULIAN', 'VEST', 'JU*****.org'),
#  ('ISAAC', 'OGLESBY', 'IS*****.org'),
#  ('MORRIS', 'MCCARTER', 'MO*****.org'),
#  ('CLIFTON', 'MALCOLM', 'CL*****.org'),
#  ('WILLARD', 'LUMPKIN', 'WI*****.org'),
#  ('DARYL', 'LARUE', 'DA*****.org'),
#  ('ROSS', 'GREY', 'RO*****.org'),
#  ('VIRGIL', 'WOFFORD', 'VI*****.org'),
#  ('ANDY', 'VANHORN', 'AN*****.org'),
#  ('MARSHALL', 'THORN', 'MA*****.org'),
#  ('SALVADOR', 'TEEL', 'SA*****.org'),
#  ('PERRY', 'SWAFFORD', 'PE*****.org'),
#  ('KIRK', 'STCLAIR', 'KI*****.org'),
#  ('SERGIO', 'STANFIELD', 'SE*****.org'),
#  ('MARION', 'OCAMPO', 'MA*****.org'),
#  ('TRACY', 'HERRMANN', 'TR*****.org'),
#  ('SETH', 'HANNON', 'SE*****.org'),
#  ('KENT', 'ARSENAULT', 'KE*****.org'),
#  ('RENE', 'MCALISTER', 'RE*****.org'),
#  ('EDUARDO', 'HIATT', 'ED*****.org'),
#  ('TERRENCE', 'GUNDERSON', 'TE*****.org'),
#  ('ENRIQUE', 'FORSYTHE', 'EN*****.org'),
#  ('FREDDIE', 'DUGGAN', 'FR*****.org'),
#  ('WADE', 'DELVALLE', 'WA*****.org'),
#  ('AUSTIN', 'CINTRON', 'AU*****.org')]

# %% [markdown]
# Code the SQL to obscure the email to this format:
# MA\*\*\*\*\*.org

# %%
# %%sql

# %% [markdown]
# ### 3. Concealing complexity
# hiding unnecessary columns that may confuse a user, especially a non-technical user, removing the need to perform JOINs.
#
# Creating a VIEW to find actors for a specific category. Having the ability to return the film title.
# Tables:
# - film
# - film_actor
# - actor
# - film_category
# - category
# Moving forward use the ```CREATE OR REPLACE``` syntax for convenience.

# %%
# %%sql
# CREATE OR REPLACE VIEW film_actor_genre AS
#     SELECT
#         first_name,
#         last_name,
#         name AS genre,
#         title
#     FROM film f
#     JOIN film_actor fa
#         ON f.film_id = fa.film_id
#     JOIN actor a
#         ON fa.actor_id = a.actor_id
#     JOIN film_category fc
#         ON f.film_id = fc.film_id
#     JOIN category c
#         ON fc.category_id = c.category_id;
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 0 rows affected.
# []

# %% [markdown]
# Verifying the view by creating a list of comedy actors.

# %%
# %%sql
# SELECT *
# FROM film_actor_genre
# WHERE genre = 'Comedy';
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 286 rows affected.
# [('JIM', 'MOSTEL', 'Comedy', 'AIRPLANE SIERRA'),
#  ('RICHARD', 'PENN', 'Comedy', 'AIRPLANE SIERRA'),
#  ('OPRAH', 'KILMER', 'Comedy', 'AIRPLANE SIERRA'),
#  ('MENA', 'HOPPER', 'Comedy', 'AIRPLANE SIERRA'),
#  ('MICHAEL', 'BOLGER', 'Comedy', 'AIRPLANE SIERRA'),
#  ('MILLA', 'KEITEL', 'Comedy', 'ANTHEM LUKE'),
#  ('OPRAH', 'KILMER', 'Comedy', 'ANTHEM LUKE'),
#  ('FRANCES', 'DAY-LEWIS', 'Comedy', 'BRINGING HYSTERICAL'),
#  ('ANGELA', 'WITHERSPOON', 'Comedy', 'BRINGING HYSTERICAL'),
#  ('HELEN', 'VOIGHT', 'Comedy', 'CAPER MOTIONS'),
#  ('AUDREY', 'OLIVIER', 'Comedy', 'CAPER MOTIONS'),
#  ('VAL', 'BOLGER', 'Comedy', 'CAPER MOTIONS'),
#  ('CHRISTIAN', 'AKROYD', 'Comedy', 'CAPER MOTIONS'),
#  ('KEVIN', 'GARLAND', 'Comedy', 'CAPER MOTIONS'),
#  ('CATE', 'MCQUEEN', 'Comedy', 'CAPER MOTIONS'),
#  ('BURT', 'TEMPLE', 'Comedy', 'CAPER MOTIONS'),
#  ('HELEN', 'VOIGHT', 'Comedy', 'CAT CONEHEADS'),
#  ('ANGELA', 'WITHERSPOON', 'Comedy', 'CAT CONEHEADS'),
#  ('LAURA', 'BRODY', 'Comedy', 'CAT CONEHEADS'),
#  ('RENEE', 'BALL', 'Comedy', 'CAT CONEHEADS'),
#  ('KIRSTEN', 'PALTROW', 'Comedy', 'CLOSER BANG'),
#  ('JODIE', 'DEGENERES', 'Comedy', 'CLOSER BANG'),
#  ('RUSSELL', 'TEMPLE', 'Comedy', 'CLOSER BANG'),
#  ('GRETA', 'MALDEN', 'Comedy', 'CLOSER BANG'),
#  ('ED', 'GUINESS', 'Comedy', 'CLOSER BANG'),
#  ('JULIA', 'FAWCETT', 'Comedy', 'CLOSER BANG'),
#  ('CAMERON', 'STREEP', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('NATALIE', 'HOPKINS', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('SCARLETT', 'DAMON', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('RENEE', 'TRACY', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('FAY', 'WINSLET', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('RUSSELL', 'TEMPLE', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('VIVIEN', 'BASINGER', 'Comedy', 'CONNECTION MICROCOSMOS'),
#  ('BOB', 'FAWCETT', 'Comedy', 'CONTROL ANTHEM'),
#  ('AUDREY', 'OLIVIER', 'Comedy', 'CONTROL ANTHEM'),
#  ('CHARLIZE', 'DENCH', 'Comedy', 'CONTROL ANTHEM'),
#  ('SISSY', 'SOBIESKI', 'Comedy', 'CRAZY HOME'),
#  ('WOODY', 'JOLIE', 'Comedy', 'CRAZY HOME'),
#  ('MEG', 'HAWKE', 'Comedy', 'CRAZY HOME'),
#  ('RUSSELL', 'BACALL', 'Comedy', 'CRAZY HOME'),
#  ('MORGAN', 'MCDORMAND', 'Comedy', 'CRAZY HOME'),
#  ('ALBERT', 'NOLTE', 'Comedy', 'CRAZY HOME'),
#  ('CATE', 'HARRIS', 'Comedy', 'CRAZY HOME'),
#  ('RUSSELL', 'TEMPLE', 'Comedy', 'CRAZY HOME'),
#  ('VIVIEN', 'BASINGER', 'Comedy', 'CRAZY HOME'),
#  ('HARVEY', 'HOPE', 'Comedy', 'CRAZY HOME'),
#  ('WILL', 'WILSON', 'Comedy', 'CRAZY HOME'),
#  ('ALAN', 'DREYFUSS', 'Comedy', 'CRAZY HOME'),
#  ('GENE', 'MCKELLEN', 'Comedy', 'CRAZY HOME'),
#  ('JOHNNY', 'LOLLOBRIGIDA', 'Comedy', 'DADDY PITTSBURGH'),
#  ('KENNETH', 'PALTROW', 'Comedy', 'DADDY PITTSBURGH'),
#  ('MICHELLE', 'MCCONAUGHEY', 'Comedy', 'DADDY PITTSBURGH'),
#  ('KEVIN', 'GARLAND', 'Comedy', 'DADDY PITTSBURGH'),
#  ('DARYL', 'CRAWFORD', 'Comedy', 'DADDY PITTSBURGH'),
#  ('CAMERON', 'STREEP', 'Comedy', 'DOOM DANCING'),
#  ('NICK', 'STALLONE', 'Comedy', 'DOOM DANCING'),
#  ('CHRISTIAN', 'AKROYD', 'Comedy', 'DOOM DANCING'),
#  ('JESSICA', 'BAILEY', 'Comedy', 'DOOM DANCING'),
#  ('MAE', 'HOFFMAN', 'Comedy', 'DOOM DANCING'),
#  ('WOODY', 'JOLIE', 'Comedy', 'DOOM DANCING'),
#  ('WARREN', 'NOLTE', 'Comedy', 'DOOM DANCING'),
#  ('CHRIS', 'DEPP', 'Comedy', 'DOOM DANCING'),
#  ('WOODY', 'JOLIE', 'Comedy', 'DOWNHILL ENOUGH'),
#  ('BEN', 'WILLIS', 'Comedy', 'DOWNHILL ENOUGH'),
#  ('DARYL', 'CRAWFORD', 'Comedy', 'DOWNHILL ENOUGH'),
#  ('HARVEY', 'HOPE', 'Comedy', 'DOWNHILL ENOUGH'),
#  ('GROUCHO', 'SINATRA', 'Comedy', 'DYING MAKER'),
#  ('MICHAEL', 'BOLGER', 'Comedy', 'DYING MAKER'),
#  ('KIRK', 'JOVOVICH', 'Comedy', 'ELEMENT FREDDY'),
#  ('ANGELA', 'HUDSON', 'Comedy', 'ELEMENT FREDDY'),
#  ('MERYL', 'GIBSON', 'Comedy', 'ELEMENT FREDDY'),
#  ('BELA', 'WALKEN', 'Comedy', 'ELEMENT FREDDY'),
#  ('SISSY', 'SOBIESKI', 'Comedy', 'FERRIS MOTHER'),
#  ('VAL', 'BOLGER', 'Comedy', 'FIREBALL PHILADELPHIA'),
#  ('JUDE', 'CRUISE', 'Comedy', 'FIREBALL PHILADELPHIA'),
#  ('ADAM', 'GRANT', 'Comedy', 'FIREBALL PHILADELPHIA'),
#  ('JAMES', 'PITT', 'Comedy', 'FIREBALL PHILADELPHIA'),
#  ('FRANCES', 'TOMEI', 'Comedy', 'FIREBALL PHILADELPHIA'),
#  ('ALBERT', 'NOLTE', 'Comedy', 'FLINTSTONES HAPPINESS'),
#  ('HUMPHREY', 'WILLIS', 'Comedy', 'FLINTSTONES HAPPINESS'),
#  ('DEBBIE', 'AKROYD', 'Comedy', 'FLINTSTONES HAPPINESS'),
#  ('BELA', 'WALKEN', 'Comedy', 'FLINTSTONES HAPPINESS'),
#  ('SCARLETT', 'DAMON', 'Comedy', 'FRANKENSTEIN STRANGER'),
#  ('BEN', 'HARRIS', 'Comedy', 'FRANKENSTEIN STRANGER'),
#  ('CAMERON', 'STREEP', 'Comedy', 'FREEDOM CLEOPATRA'),
#  ('ALEC', 'WAYNE', 'Comedy', 'FREEDOM CLEOPATRA'),
#  ('TOM', 'MCKELLEN', 'Comedy', 'FREEDOM CLEOPATRA'),
#  ('RAY', 'JOHANSSON', 'Comedy', 'FREEDOM CLEOPATRA'),
#  ('CHRISTOPHER', 'BERRY', 'Comedy', 'FREEDOM CLEOPATRA'),
#  ('GROUCHO', 'DUNST', 'Comedy', 'GOLD RIVER'),
#  ('RUSSELL', 'TEMPLE', 'Comedy', 'GOLD RIVER'),
#  ('UMA', 'WOOD', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('JULIA', 'BARRYMORE', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('JAYNE', 'NEESON', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('ADAM', 'GRANT', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('SEAN', 'GUINESS', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('RICHARD', 'PENN', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('GROUCHO', 'WILLIAMS', 'Comedy', 'GROUNDHOG UNCUT'),
#  ('CARMEN', 'HUNT', 'Comedy', 'GUNFIGHT MOON'),
#  ('GINA', 'DEGENERES', 'Comedy', 'GUNFIGHT MOON'),
#  ('KEVIN', 'GARLAND', 'Comedy', 'GUNFIGHT MOON'),
#  ('RUSSELL', 'CLOSE', 'Comedy', 'GUNFIGHT MOON'),
#  ('BOB', 'FAWCETT', 'Comedy', 'HATE HANDICAP'),
#  ('KEVIN', 'BLOOM', 'Comedy', 'HATE HANDICAP'),
#  ('RIVER', 'DEAN', 'Comedy', 'HATE HANDICAP'),
#  ('BURT', 'DUKAKIS', 'Comedy', 'HEAVEN FREEDOM'),
#  ('KIRK', 'JOVOVICH', 'Comedy', 'HEAVEN FREEDOM'),
#  ('CHARLIZE', 'DENCH', 'Comedy', 'HEAVEN FREEDOM'),
#  ('ADAM', 'HOPPER', 'Comedy', 'HEAVEN FREEDOM'),
#  ('RICHARD', 'PENN', 'Comedy', 'HEAVEN FREEDOM'),
#  ('MORGAN', 'WILLIAMS', 'Comedy', 'HEAVEN FREEDOM'),
#  ('ALBERT', 'JOHANSSON', 'Comedy', 'HEAVEN FREEDOM'),
#  ('FAY', 'WINSLET', 'Comedy', 'HEAVEN FREEDOM'),
#  ('OPRAH', 'KILMER', 'Comedy', 'HEAVEN FREEDOM'),
#  ('GREGORY', 'GOODING', 'Comedy', 'HEAVEN FREEDOM'),
#  ('JAYNE', 'NEESON', 'Comedy', 'HEDWIG ALTER'),
#  ('JAMES', 'PITT', 'Comedy', 'HEDWIG ALTER'),
#  ('GENE', 'HOPKINS', 'Comedy', 'HEDWIG ALTER'),
#  ('DEBBIE', 'AKROYD', 'Comedy', 'HEDWIG ALTER'),
#  ('KIRSTEN', 'AKROYD', 'Comedy', 'HURRICANE AFFAIR'),
#  ('RUSSELL', 'BACALL', 'Comedy', 'HURRICANE AFFAIR'),
#  ('FAY', 'WINSLET', 'Comedy', 'HURRICANE AFFAIR'),
#  ('ALEC', 'WAYNE', 'Comedy', 'HUSTLER PARTY'),
#  ('ANGELINA', 'ASTAIRE', 'Comedy', 'HUSTLER PARTY'),
#  ('MINNIE', 'KILMER', 'Comedy', 'HUSTLER PARTY'),
#  ('CHRISTOPHER', 'WEST', 'Comedy', 'HUSTLER PARTY'),
#  ('HELEN', 'VOIGHT', 'Comedy', 'JAWS HARRY'),
#  ('LUCILLE', 'TRACY', 'Comedy', 'JAWS HARRY'),
#  ('PARKER', 'GOLDBERG', 'Comedy', 'JAWS HARRY'),
#  ('MINNIE', 'ZELLWEGER', 'Comedy', 'JAWS HARRY'),
#  ('GRETA', 'KEITEL', 'Comedy', 'JAWS HARRY'),
#  ('CUBA', 'OLIVIER', 'Comedy', 'KNOCK WARLOCK'),
#  ('WOODY', 'HOFFMAN', 'Comedy', 'KNOCK WARLOCK'),
#  ('AUDREY', 'OLIVIER', 'Comedy', 'KNOCK WARLOCK'),
#  ('TOM', 'MIRANDA', 'Comedy', 'KNOCK WARLOCK'),
#  ('REESE', 'KILMER', 'Comedy', 'KNOCK WARLOCK'),
#  ('JUDE', 'CRUISE', 'Comedy', 'KNOCK WARLOCK'),
#  ('CHRISTIAN', 'GABLE', 'Comedy', 'LIFE TWISTED'),
#  ('UMA', 'WOOD', 'Comedy', 'LIFE TWISTED'),
#  ('MINNIE', 'ZELLWEGER', 'Comedy', 'LIFE TWISTED'),
#  ('DARYL', 'WAHLBERG', 'Comedy', 'LIFE TWISTED'),
#  ('CHRISTOPHER', 'WEST', 'Comedy', 'LIFE TWISTED'),
#  ('GENE', 'MCKELLEN', 'Comedy', 'LIFE TWISTED'),
#  ('MATTHEW', 'CARREY', 'Comedy', 'LIFE TWISTED'),
#  ('REESE', 'WEST', 'Comedy', 'LIFE TWISTED'),
#  ('UMA', 'WOOD', 'Comedy', 'LION UNCUT'),
#  ('PENELOPE', 'PINKETT', 'Comedy', 'LION UNCUT'),
#  ('BELA', 'WALKEN', 'Comedy', 'LION UNCUT'),
#  ('RIP', 'CRAWFORD', 'Comedy', 'LONELY ELEPHANT'),
#  ('VAL', 'BOLGER', 'Comedy', 'LONELY ELEPHANT'),
#  ('KENNETH', 'PALTROW', 'Comedy', 'LONELY ELEPHANT'),
#  ('BEN', 'WILLIS', 'Comedy', 'LONELY ELEPHANT'),
#  ('JAMES', 'PITT', 'Comedy', 'LONELY ELEPHANT'),
#  ('CHARLIZE', 'DENCH', 'Comedy', 'LONELY ELEPHANT'),
#  ('SEAN', 'GUINESS', 'Comedy', 'LONELY ELEPHANT'),
#  ('WALTER', 'TORN', 'Comedy', 'LONELY ELEPHANT'),
#  ('EWAN', 'GOODING', 'Comedy', 'LONELY ELEPHANT'),
#  ('GROUCHO', 'WILLIAMS', 'Comedy', 'LONELY ELEPHANT'),
#  ('ALAN', 'DREYFUSS', 'Comedy', 'LONELY ELEPHANT'),
#  ('ROCK', 'DUKAKIS', 'Comedy', 'LONELY ELEPHANT'),
#  ('NICK', 'WAHLBERG', 'Comedy', 'MALLRATS UNITED'),
#  ('VAL', 'BOLGER', 'Comedy', 'MALLRATS UNITED'),
#  ('CAMERON', 'ZELLWEGER', 'Comedy', 'MALLRATS UNITED'),
#  ('VIVIEN', 'BASINGER', 'Comedy', 'MALLRATS UNITED'),
#  ('MARY', 'KEITEL', 'Comedy', 'MALLRATS UNITED'),
#  ('TOM', 'MIRANDA', 'Comedy', 'MEMENTO ZOOLANDER'),
#  ('ANGELINA', 'ASTAIRE', 'Comedy', 'MEMENTO ZOOLANDER'),
#  ('KIRSTEN', 'AKROYD', 'Comedy', 'MEMENTO ZOOLANDER'),
#  ('SUSAN', 'DAVIS', 'Comedy', 'MEMENTO ZOOLANDER'),
#  ('ALBERT', 'NOLTE', 'Comedy', 'MEMENTO ZOOLANDER'),
#  ('MARY', 'KEITEL', 'Comedy', 'MEMENTO ZOOLANDER'),
#  ('NICK', 'STALLONE', 'Comedy', 'MULAN MOON'),
#  ('ANGELINA', 'ASTAIRE', 'Comedy', 'MULAN MOON'),
#  ('GRETA', 'MALDEN', 'Comedy', 'MULAN MOON'),
#  ('MATTHEW', 'CARREY', 'Comedy', 'MULAN MOON'),
#  ('JULIA', 'FAWCETT', 'Comedy', 'MULAN MOON'),
#  ('SCARLETT', 'DAMON', 'Comedy', 'MYSTIC TRUMAN'),
#  ('KEVIN', 'GARLAND', 'Comedy', 'MYSTIC TRUMAN'),
#  ('RIVER', 'DEAN', 'Comedy', 'MYSTIC TRUMAN'),
#  ('HUMPHREY', 'WILLIS', 'Comedy', 'MYSTIC TRUMAN'),
#  ('CHRISTIAN', 'AKROYD', 'Comedy', 'OPERATION OPERATION'),
#  ('ADAM', 'GRANT', 'Comedy', 'OPERATION OPERATION'),
#  ('GREGORY', 'GOODING', 'Comedy', 'OPERATION OPERATION'),
#  ('JODIE', 'DEGENERES', 'Comedy', 'PARADISE SABRINA'),
#  ('PENELOPE', 'CRONYN', 'Comedy', 'PARADISE SABRINA'),
#  ('SYLVESTER', 'DERN', 'Comedy', 'PARADISE SABRINA'),
#  ('JEFF', 'SILVERSTONE', 'Comedy', 'PARADISE SABRINA'),
#  ('RIVER', 'DEAN', 'Comedy', 'PARTY KNOCK'),
#  ('CHRIS', 'DEPP', 'Comedy', 'PARTY KNOCK'),
#  ('KARL', 'BERRY', 'Comedy', 'PERFECT GROOVE'),
#  ('NATALIE', 'HOPKINS', 'Comedy', 'PERFECT GROOVE'),
#  ('BEN', 'WILLIS', 'Comedy', 'PERFECT GROOVE'),
#  ('JIM', 'MOSTEL', 'Comedy', 'PERFECT GROOVE'),
#  ('JAYNE', 'NOLTE', 'Comedy', 'PERFECT GROOVE'),
#  ('LAURENCE', 'BULLOCK', 'Comedy', 'PERFECT GROOVE'),
#  ('KIRSTEN', 'PALTROW', 'Comedy', 'PINOCCHIO SIMON'),
#  ('REESE', 'KILMER', 'Comedy', 'PINOCCHIO SIMON'),
#  ('RALPH', 'CRUZ', 'Comedy', 'PINOCCHIO SIMON'),
#  ('ELLEN', 'PRESLEY', 'Comedy', 'PINOCCHIO SIMON'),
#  ('CAMERON', 'ZELLWEGER', 'Comedy', 'PINOCCHIO SIMON'),
#  ('MORGAN', 'HOPKINS', 'Comedy', 'PINOCCHIO SIMON'),
#  ('RIVER', 'DEAN', 'Comedy', 'PINOCCHIO SIMON'),
#  ('BEN', 'HARRIS', 'Comedy', 'PINOCCHIO SIMON'),
#  ('MERYL', 'GIBSON', 'Comedy', 'PINOCCHIO SIMON'),
#  ('LAURA', 'BRODY', 'Comedy', 'PINOCCHIO SIMON'),
#  ('JOHN', 'SUVARI', 'Comedy', 'PINOCCHIO SIMON'),
#  ('CAMERON', 'STREEP', 'Comedy', 'PURE RUNNER'),
#  ('MILLA', 'KEITEL', 'Comedy', 'PURE RUNNER'),
#  ('NICK', 'WAHLBERG', 'Comedy', 'RUSHMORE MERMAID'),
#  ('MILLA', 'PECK', 'Comedy', 'RUSHMORE MERMAID'),
#  ('JOHNNY', 'CAGE', 'Comedy', 'RUSHMORE MERMAID'),
#  ('PENELOPE', 'PINKETT', 'Comedy', 'RUSHMORE MERMAID'),
#  ('HENRY', 'BERRY', 'Comedy', 'RUSHMORE MERMAID'),
#  ('HARRISON', 'BALE', 'Comedy', 'RUSHMORE MERMAID'),
#  ('FAY', 'WOOD', 'Comedy', 'RUSHMORE MERMAID'),
#  ('BOB', 'FAWCETT', 'Comedy', 'SADDLE ANTITRUST'),
#  ('ADAM', 'HOPPER', 'Comedy', 'SADDLE ANTITRUST'),
#  ('MINNIE', 'KILMER', 'Comedy', 'SADDLE ANTITRUST'),
#  ('ANGELINA', 'ASTAIRE', 'Comedy', 'SATURN NAME'),
#  ('CHRIS', 'BRIDGES', 'Comedy', 'SATURN NAME'),
#  ('SUSAN', 'DAVIS', 'Comedy', 'SEARCHERS WAIT'),
#  ('GINA', 'DEGENERES', 'Comedy', 'SEARCHERS WAIT'),
#  ('CATE', 'MCQUEEN', 'Comedy', 'SEARCHERS WAIT'),
#  ('ROCK', 'DUKAKIS', 'Comedy', 'SEARCHERS WAIT'),
#  ('SCARLETT', 'BENING', 'Comedy', 'SNATCH SLIPPER'),
#  ('CATE', 'MCQUEEN', 'Comedy', 'SNATCH SLIPPER'),
#  ('RITA', 'REYNOLDS', 'Comedy', 'SNATCH SLIPPER'),
#  ('WALTER', 'TORN', 'Comedy', 'STAGE WORLD'),
#  ('BELA', 'WALKEN', 'Comedy', 'STAGE WORLD'),
#  ('GREG', 'CHAPLIN', 'Comedy', 'STRICTLY SCARFACE'),
#  ('DARYL', 'CRAWFORD', 'Comedy', 'STRICTLY SCARFACE'),
#  ('WHOOPI', 'HURT', 'Comedy', 'STRICTLY SCARFACE'),
#  ('ALAN', 'DREYFUSS', 'Comedy', 'STRICTLY SCARFACE'),
#  ('JENNIFER', 'DAVIS', 'Comedy', 'SUBMARINE BED'),
#  ('PENELOPE', 'PINKETT', 'Comedy', 'SUBMARINE BED'),
#  ('CHRISTIAN', 'AKROYD', 'Comedy', 'SUBMARINE BED'),
#  ('RALPH', 'CRUZ', 'Comedy', 'SUBMARINE BED'),
#  ('SEAN', 'GUINESS', 'Comedy', 'SUBMARINE BED'),
#  ('SIDNEY', 'CROWE', 'Comedy', 'SUBMARINE BED'),
#  ('GROUCHO', 'DUNST', 'Comedy', 'SUBMARINE BED'),
#  ('WARREN', 'JACKMAN', 'Comedy', 'SUBMARINE BED'),
#  ('SCARLETT', 'BENING', 'Comedy', 'SUBMARINE BED'),
#  ('GREGORY', 'GOODING', 'Comedy', 'SUBMARINE BED'),
#  ('MARY', 'KEITEL', 'Comedy', 'SUBMARINE BED'),
#  ('KARL', 'BERRY', 'Comedy', 'SWEDEN SHINING'),
#  ('KEVIN', 'BLOOM', 'Comedy', 'SWEDEN SHINING'),
#  ('MARY', 'TANDY', 'Comedy', 'SWEDEN SHINING'),
#  ('ALBERT', 'JOHANSSON', 'Comedy', 'SWEDEN SHINING'),
#  ('MARY', 'KEITEL', 'Comedy', 'SWEDEN SHINING'),
#  ('GREG', 'CHAPLIN', 'Comedy', 'TRAINSPOTTING STRANGERS'),
#  ('GINA', 'DEGENERES', 'Comedy', 'TRAINSPOTTING STRANGERS'),
#  ('RITA', 'REYNOLDS', 'Comedy', 'TRAINSPOTTING STRANGERS'),
#  ('RUSSELL', 'TEMPLE', 'Comedy', 'TRAINSPOTTING STRANGERS'),
#  ('RIP', 'CRAWFORD', 'Comedy', 'TRAMP OTHERS'),
#  ('SIDNEY', 'CROWE', 'Comedy', 'TRAMP OTHERS'),
#  ('JADA', 'RYDER', 'Comedy', 'TRAMP OTHERS'),
#  ('RIVER', 'DEAN', 'Comedy', 'TRAMP OTHERS'),
#  ('RENEE', 'BALL', 'Comedy', 'TRAMP OTHERS'),
#  ('BELA', 'WALKEN', 'Comedy', 'TRAMP OTHERS'),
#  ('TOM', 'MIRANDA', 'Comedy', 'VALLEY PACKER'),
#  ('CAMERON', 'WRAY', 'Comedy', 'VALLEY PACKER'),
#  ('BEN', 'WILLIS', 'Comedy', 'VALLEY PACKER'),
#  ('SUSAN', 'DAVIS', 'Comedy', 'VALLEY PACKER'),
#  ('ZERO', 'CAGE', 'Comedy', 'VELVET TERMINATOR'),
#  ('JOHNNY', 'CAGE', 'Comedy', 'VELVET TERMINATOR'),
#  ('ANGELA', 'HUDSON', 'Comedy', 'VELVET TERMINATOR'),
#  ('SEAN', 'WILLIAMS', 'Comedy', 'VELVET TERMINATOR'),
#  ('CARY', 'MCCONAUGHEY', 'Comedy', 'VELVET TERMINATOR'),
#  ('CUBA', 'ALLEN', 'Comedy', 'VELVET TERMINATOR'),
#  ('DARYL', 'CRAWFORD', 'Comedy', 'VELVET TERMINATOR'),
#  ('MINNIE', 'KILMER', 'Comedy', 'VELVET TERMINATOR'),
#  ('MERYL', 'ALLEN', 'Comedy', 'VELVET TERMINATOR'),
#  ('PENELOPE', 'GUINESS', 'Comedy', 'VERTIGO NORTHWEST'),
#  ('DAN', 'STREEP', 'Comedy', 'VERTIGO NORTHWEST'),
#  ('WARREN', 'JACKMAN', 'Comedy', 'VERTIGO NORTHWEST'),
#  ('BELA', 'WALKEN', 'Comedy', 'VERTIGO NORTHWEST'),
#  ('SISSY', 'SOBIESKI', 'Comedy', 'WISDOM WORKER'),
#  ('REESE', 'KILMER', 'Comedy', 'WISDOM WORKER'),
#  ('WOODY', 'JOLIE', 'Comedy', 'WISDOM WORKER'),
#  ('JIM', 'MOSTEL', 'Comedy', 'WISDOM WORKER'),
#  ('SUSAN', 'DAVIS', 'Comedy', 'WISDOM WORKER'),
#  ('LAURA', 'BRODY', 'Comedy', 'WISDOM WORKER'),
#  ('WILLIAM', 'HACKMAN', 'Comedy', 'WISDOM WORKER'),
#  ('IAN', 'TANDY', 'Comedy', 'ZORRO ARK'),
#  ('NICK', 'DEGENERES', 'Comedy', 'ZORRO ARK'),
#  ('LISA', 'MONROE', 'Comedy', 'ZORRO ARK')]

# %% [markdown]
# ### 4. Data aggregation
# Many BI applications, such as Tableau, PowerBI, etc., query VIEWS, not tables. Analysts typically only have access to VIEWS.
#
# Showing the total rental revenue for each film category per month. The results can be used for a monthly report to help managers decide what new films to add to inventory.

# %% [markdown]
# payment
#     rental_id
# rental
#     inventory_id
# inventory
#     film_id
# film
#     film_id
# film_category
#     category_id
# category

# %%
# %%sql
# CREATE OR REPLACE VIEW monthly_sales_by_film_category AS
#     SELECT
#         LEFT(rental_date, 7) AS rental_date_month,
#         name AS genre,
#         SUM(amount) AS total_rental_revenue
#     FROM payment p
#     JOIN rental r
#         ON p.rental_id = r.rental_id
#     JOIN inventory i
#         ON r.inventory_id = i.inventory_id
#     JOIN film f
#         ON i.film_id = f.film_id
#     JOIN film_category fc
#         ON f.film_id = fc.film_id
#     JOIN category c
#         ON fc.category_id = c.category_id
#     GROUP BY
#         rental_date_month,
#         genre;
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 0 rows affected.
# []

# %% [markdown]
# Validating the VIEW by listing the aggregated rental revenue for August 2005 sorted by the total_rental_revenue.

# %%
# %%sql
# SELECT *
# FROM monthly_sales_by_film_category
# WHERE rental_date_month = '2005-08';
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 16 rows affected.
# [('2005-08', 'Animation', Decimal('1654.92')),
#  ('2005-08', 'Drama', Decimal('1526.47')),
#  ('2005-08', 'Music', Decimal('1163.23')),
#  ('2005-08', 'Comedy', Decimal('1593.58')),
#  ('2005-08', 'Games', Decimal('1508.48')),
#  ('2005-08', 'Sports', Decimal('1962.68')),
#  ('2005-08', 'Children', Decimal('1315.68')),
#  ('2005-08', 'Family', Decimal('1474.16')),
#  ('2005-08', 'New', Decimal('1626.54')),
#  ('2005-08', 'Action', Decimal('1463.16')),
#  ('2005-08', 'Documentary', Decimal('1517.31')),
#  ('2005-08', 'Horror', Decimal('1342.01')),
#  ('2005-08', 'Travel', Decimal('1244.02')),
#  ('2005-08', 'Classics', Decimal('1371.52')),
#  ('2005-08', 'Foreign', Decimal('1599.23')),
#  ('2005-08', 'Sci-Fi', Decimal('1707.15'))]

# %% [markdown]
# ### UPDATE a VIEW example
#
# updating the customer last_name for Linda Williams to Kennedy. Directly UPDATE the active_customer VIEW and not the customer table.

# %%
# %%sql
# UPDATE active_customer
# SET last_name = 'Kennedy'
# WHERE first_name = 'Linda'
#     AND last_name = 'Williams';
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 1 rows affected.
# []

# %% [markdown]
# Confirming the change in the active_customer VIEW.

# %%
# %%sql
# SELECT *
# FROM active_customer
# WHERE first_name = 'Linda';
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 1 rows affected.
# [('LINDA', 'Kennedy', 'LI*****.org')]

# %% [markdown]
# Confirming the change in the customer table.

# %%
# %%sql
# SELECT *
# FROM customer
# WHERE first_name = 'Linda';
# Out:
#  * mysql://itaylmub_dba:***@lmu.build/itaylmub_sakila
# 1 rows affected.
# [(3, 1, 'LINDA', 'Kennedy', 'LINDA.WILLIAMS@sakilacustomer.org', 7, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2022, 3, 28, 9, 8, 51))]
